# %% [markdown]
# ## LSTM model ##
#
# - This is an exploratory notebook to find the best hyperparameters for the model so that it is not overfitting neither is it underfitting

# %% [markdown]
# #### Fourier transforms####
#
# - eliminate noise and create approximations of the real stock movement.
# - creates a series of sine waves with different amplitudes and frames. Wen combined, these sine waves approximate the original function.
# - we use them to extract global and local trends in the stock price.
#
# #### Stacked autoencoders ####
#
# - to find the missing correlations, we can find new types of features that affect stock movements.
# - Autoencode is a neural network model that seeks to learn a compressed representation of an input.
#     - They are unsupervised but are trained with supervised learning methods. They are typically trained as part of a broader model that attemps to recreate the input.
#     - They have a design with a bottleneck at the midpoint from which the reconstruction of the input data is performed.
#     - The most commong use isa learned or automatic feature extraction model.
#     - We can take the data up until the bottleneck and use that as a fixed length vector that provides a compressed representation of hte input data, can be used for supervised learning model, visualization or more generally for dimensionality reduction.
#   #### LSTM Autoencoder:
#       - Implementation of autoencoder for sequence data usin and Encoder- Decoder LSTM architecture.
#       - an encoder-decoder LSTM is configured to read the input sequence, encode it, decode it, and recreate it. The performance is evaluated based on the model's ability to recreate the input sequence.
#       - When the model has a desired level of performance, the decoder part of the model may be removed and we will have just hte encoder part.
#       - Composite model: two decoders used to predict the next frame in the sequence and one to reconstruct frames in the sequence.
#
# ##### steps:
# - perform statistical checks for the 'quality' of the data. Make sure the data does not have heteroskedasticity, multicollinearity, or serial correlation.
# - create feature importance, use XGBoost to do that.
# - Heteroskedasticity: when the difference between predicted value by a regression and the real value is dependent on the data i.e. error grows when the data point grows along the x-axis.
# - Serial Correlation: when one data is a formula of another feature.
#
# ##### PCA:
# - reduce the dimensionality of the features created from autoencoders, using eigen portfolios

# %%
# To be crystal clear, the top of your code file must have the following 4 lines before any others;
from numpy.random import seed
seed(42)
from tensorflow import set_random_seed
set_random_seed(42)

# %%
# !pip install python-decouple
# Out:
# Requirement already satisfied: python-decouple in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (3.1)
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install quandl
# Out:
# Requirement already satisfied: quandl in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (3.4.8)
# Requirement already satisfied: ndg-httpsclient in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (0.5.1)
# Requirement already satisfied: inflection>=0.3.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (0.3.1)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (1.11.0)
# Requirement already satisfied: pandas>=0.14 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (0.24.2)
# Requirement already satisfied: numpy>=1.8 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (1.16.4)
# Requirement already satisfied: pyOpenSSL in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (18.0.0)
# Requirement already satisfied: more-itertools<=5.0.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (4.1.0)
# Requirement already satisfied: pyasn1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (0.4.7)
# Requirement already satisfied: requests>=2.7.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (2.20.0)
# Requirement already satisfied: python-dateutil in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from quandl) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pandas>=0.14->quandl) (2018.4)
# Requirement already satisfied: cryptography>=2.2.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pyOpenSSL->quandl) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (2.6)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from cryptography>=2.2.1->pyOpenSSL->quandl) (1.11.5)
# Requirement already satisfied: asn1crypto>=0.21.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from cryptography>=2.2.1->pyOpenSSL->quandl) (0.24.0)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.2.1->pyOpenSSL->quandl) (2.18)
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install alpha_vantage
# Out:
# Requirement already satisfied: alpha_vantage in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (2.1.1)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from alpha_vantage) (2.20.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests->alpha_vantage) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests->alpha_vantage) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests->alpha_vantage) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests->alpha_vantage) (2019.6.16)
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install intrinio-sdk
# Out:
# Requirement already satisfied: intrinio-sdk in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (4.0.0)
# Requirement already satisfied: six>=1.10 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from intrinio-sdk) (1.11.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from intrinio-sdk) (2019.6.16)
# Requirement already satisfied: python-dateutil in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from intrinio-sdk) (2.7.3)
# Requirement already satisfied: urllib3>=1.15 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from intrinio-sdk) (1.23)
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import quandl
import datetime
from decouple import config
import math
# sklearn imports
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
import matplotlib.pyplot as plt
# keras imports
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.layers import RepeatVector, TimeDistributed
# notebook imports
from fin_data_fundamentals import find_fundamentals
from fin_data_fundamentals import get_fundamentals
from alpha_vantage.foreignexchange import ForeignExchange
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.timeseries import TimeSeries
from fin_data import DailyTimeSeries
from fracdiff import FractionalDifferentiation as fd
# Out:
# Using TensorFlow backend.

# %%
from fin_data import DailyTimeSeries
import numpy as np
import pandas as pd
import os, sys
import matplotlib.pyplot as plt

class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout


pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Let's pull in the data:

# %%
# We will experiment with Tesla stock

tesla = DailyTimeSeries('TSLA')

df = tesla.initiate()
# Out:
# ###################################################################
#  Ticker:  TSLA
#  Last Refreshed:  2019-09-23 10:25:27
#  Data Retrieved:  Daily Time Series with Splits and Dividend Events
#  ###################################################################

# %%
df.head()
# Out:
#             TSLA_open  TSLA_high  TSLA_low  TSLA_close  TSLA_adjusted_close  \
# date
# 2010-06-29      19.00    24.9984     17.54       23.89                23.89
# 2010-06-30      25.79    30.4190     23.30       23.83                23.83
# 2010-07-01      25.00    25.9200     20.27       21.96                21.96
# 2010-07-02      23.00    23.0998     18.71       19.20                19.20
# 2010-07-06      20.00    20.0000     15.83       16.11                16.11
#
#             TSLA_volume  TSLA_dividend_amount
# date
# 2010-06-29   18766300.0                   0.0
# 2010-06-30   17187100.0                   0.0
# 2010-07-01    8218800.0                   0.0
# 2010-07-02    5139800.0                   0.0
# 2010-07-06    6866900.0                   0.0

# %% [markdown]
# plt.figure(figsize=(20,12))
#
# plt.plot(df['TSLA close'], color = 'teal')
# plt.plot(df['5. adjusted close'], color = 'red');

# %% [markdown]
# #### Adding Indicators ##
#
# Add indicators, technical, securities, and macro to the dataframe

# %%
# add the fundamentals,

fund_list = ["operatingrevenue", "totalrevenue", "netincome", "totaloperatingexpenses", "totalgrossprofit", "totaloperatingincome", "totalpretaxincome", "weightedavebasicdilutedsharesos", "cashdividendspershare", "totalcostofrevenue"]

# not a complete list of fundamentals that I can pull in from the API, but this is good so far.

# %%
df_fund = tesla.add_fundamentals(df, fund_list)
# Out:
# ###################################################################
#  Ticker:  TSLA
#  Fundamentals Retrieved:  ['TSLA_open' 'TSLA_high' 'TSLA_low' 'TSLA_close' 'TSLA_adjusted_close'
#  'TSLA_volume' 'TSLA_dividend_amount' 'TSLA_operatingrevenue'
#  'TSLA_totalrevenue' 'TSLA_netincome' 'TSLA_totaloperatingexpenses'
#  'TSLA_totalgrossprofit' 'TSLA_totaloperatingincome'
#  'TSLA_totalpretaxincome' 'TSLA_weightedavebasicdilutedsharesos'
#  'TSLA_cashdividendspershare' 'TSLA_totalcostofrevenue']
#  ###################################################################
# ###################################################################
#  Ticker:  TSLA
#  Retrieved Data Start Date:  2011-11-14
#  Retrieved Data End Date:  2019-07-29
#  Data Retrieved:  ['TSLA_operatingrevenue', 'TSLA_totalrevenue', 'TSLA_netincome', 'TSLA_totaloperatingexpenses', 'TSLA_totalgrossprofit', 'TSLA_totaloperatingincome', 'TSLA_totalpretaxincome', 'TSLA_weightedavebasicdilutedsharesos', 'TSLA_cashdividendspershare', 'TSLA_totalcostofrevenue']
#  ###################################################################

# %%
funs = ['totalrevenue',  'totalcostofrevenue', 'totalgrossprofit', 'totalpretaxincome', 'weightedavebasicdilutedsharesos', 'cashdividendspershare']
techs = ['SMA', 'WMA', 'STOCH', 'ROC', 'AROON']
macros = ['housing_index', 'confidence_index', 'trade_index', 'longterm_rates', 'shortterm_rates']

# %%
df_fund.head()
# Out:
#             TSLA_open  TSLA_high  TSLA_low  TSLA_close  TSLA_adjusted_close  \
# date
# 2010-06-29      19.00    24.9984     17.54       23.89                23.89
# 2010-06-30      25.79    30.4190     23.30       23.83                23.83
# 2010-07-01      25.00    25.9200     20.27       21.96                21.96
# 2010-07-02      23.00    23.0998     18.71       19.20                19.20
# 2010-07-06      20.00    20.0000     15.83       16.11                16.11
#
#             TSLA_volume  TSLA_dividend_amount  TSLA_operatingrevenue  \
# date
# 2010-06-29   18766300.0                   0.0             31241000.0
# 2010-06-30   17187100.0                   0.0             31241000.0
# 2010-07-01    8218800.0                   0.0             31241000.0
# 2010-07-02    5139800.0                   0.0             31241000.0
# 2010-07-06    6866900.0                   0.0             31241000.0
#
#             TSLA_totalrevenue  TSLA_netincome  TSLA_totaloperatingexpenses  \
# date
# 2010-06-29         31241000.0     -34935000.0                   47130000.0
# 2010-06-30         31241000.0     -34935000.0                   47130000.0
# 2010-07-01         31241000.0     -34935000.0                   47130000.0
# 2010-07-02         31241000.0     -34935000.0                   47130000.0
# 2010-07-06         31241000.0     -34935000.0                   47130000.0
#
#             TSLA_totalgrossprofit  TSLA_totaloperatingincome  \
# date
# 2010-06-29              9296000.0                -37834000.0
# 2010-06-30              9296000.0                -37834000.0
# 2010-07-01              9296000.0                -37834000.0
# 2010-07-02              9296000.0                -37834000.0
# 2010-07-06              9296000.0                -37834000.0
#
#             TSLA_totalpretaxincome  TSLA_weightedavebasicdilutedsharesos  \
# date
# 2010-06-29             -34852000.0                            92270721.0
# 2010-06-30             -34852000.0                            92270721.0
# 2010-07-01             -34852000.0                            92270721.0
# 2010-07-02             -34852000.0                            92270721.0
# 2010-07-06             -34852000.0                            92270721.0
#
#             TSLA_cashdividendspershare  TSLA_totalcostofrevenue
# date
# 2010-06-29                         0.0               21945000.0
# 2010-06-30                         0.0               21945000.0
# 2010-07-01                         0.0               21945000.0
# 2010-07-02                         0.0               21945000.0
# 2010-07-06                         0.0               21945000.0

# %%
# Add data with all the indicators:

def tech_company_data(ticker):
    """
    Containes Tech Index
    """    
    dts = DailyTimeSeries(ticker)
    df = dts.initiate()
    with HiddenPrints():
        df = dts.add_securities(['XLK', 'vix', 'SPX'], primary_df=df)
        df = dts.add_technicals(['SMA', 'EMA', 'MACD', 'STOCH', 
                                   'RSI', 'ADX', 'CCI', 'BBANDS', 
                                   'AD', 'OBV'], 
                                  primary_df=df)
        df = dts.add_macro(primary_df=df, 
                             indices=['housing_index', 'confidence_index', 'trade_index', 'longterm_rates'])
    
    return df

# %%
df = tech_company_data('TSLA')
# Out:
# ###################################################################
#  Ticker:  TSLA
#  Last Refreshed:  2019-09-23 10:25:27
#  Data Retrieved:  Daily Time Series with Splits and Dividend Events
#  ###################################################################
# /home/ec2-user/SageMaker/fin_data.py:276: UserWarning: The latest value available for Housing Index is from January 2019.
#   warnings.warn("The latest value available for Housing Index is from January 2019.")

# %%
df.head()
# Out:
#             TSLA_open  TSLA_high  TSLA_low  TSLA_close  TSLA_adjusted_close  \
# date
# 2010-08-24      19.25     19.710     18.95       19.20                19.20
# 2010-08-25      19.16     19.980     18.56       19.90                19.90
# 2010-08-26      19.89     20.270     19.60       19.75                19.75
# 2010-08-27      19.75     19.865     19.50       19.70                19.70
# 2010-08-30      19.70     20.190     19.61       19.87                19.87
#
#             TSLA_volume  TSLA_dividend_amount  XLK_open  XLK_high  XLK_low  \
# date
# 2010-08-24     673100.0                   0.0     20.93    21.079    20.77
# 2010-08-25     503300.0                   0.0     20.74    21.090    20.69
# 2010-08-26     433800.0                   0.0     21.10    21.130    20.76
# 2010-08-27     379600.0                   0.0     20.91    21.050    20.58
# 2010-08-30     732800.0                   0.0     20.93    21.090    20.76
#
#             XLK_close  XLK_adjusted_close  XLK_volume  XLK_dividend_amount  \
# date
# 2010-08-24      20.87             17.9672  10590300.0                  0.0
# 2010-08-25      21.00             18.0791  11052900.0                  0.0
# 2010-08-26      20.79             17.8983  10154700.0                  0.0
# 2010-08-27      21.04             18.1136  14991700.0                  0.0
# 2010-08-30      20.76             17.8725   7593500.0                  0.0
#
#             XLK_split_coefficient  vix_open  vix_high  vix_low  vix_close  \
# date
# 2010-08-24                    1.0     27.91     28.77    26.32      27.46
# 2010-08-25                    1.0     28.30     28.92    26.46      26.70
# 2010-08-26                    1.0     26.45     27.55    25.86      27.37
# 2010-08-27                    1.0     26.50     28.11    24.41      24.45
# 2010-08-30                    1.0     25.88     27.21    25.41      27.21
#
#             vix_adjusted_close  vix_volume  vix_dividend_amount  \
# date
# 2010-08-24               27.46         0.0                  0.0
# 2010-08-25               26.70         0.0                  0.0
# 2010-08-26               27.37         0.0                  0.0
# 2010-08-27               24.45         0.0                  0.0
# 2010-08-30               27.21         0.0                  0.0
#
#             vix_split_coefficient  SPX_open  SPX_high    SPX_low  SPX_close  \
# date
# 2010-08-24                    1.0   1063.20   1063.20  1046.6801    1051.87
# 2010-08-25                    1.0   1048.98   1059.38  1039.8300    1055.33
# 2010-08-26                    1.0   1056.28   1061.45  1045.4000    1047.22
# 2010-08-27                    1.0   1049.27   1065.21  1039.7000    1064.59
# 2010-08-30                    1.0   1062.90   1064.40  1048.7900    1048.92
#
#             SPX_adjusted_close    SPX_volume  SPX_dividend_amount  \
# date
# 2010-08-24             1051.87  4.436330e+09                  0.0
# 2010-08-25             1055.33  4.360190e+09                  0.0
# 2010-08-26             1047.22  3.646710e+09                  0.0
# 2010-08-27             1064.59  4.102460e+09                  0.0
# 2010-08-30             1048.92  2.917990e+09                  0.0
#
#             SPX_split_coefficient  TSLA_SMA  TSLA_EMA  TSLA_MACD_Hist  \
# date
# 2010-08-24                    1.0   19.5775   19.3641         -0.0444
# 2010-08-25                    1.0   19.5365   19.4152          0.0149
# 2010-08-26                    1.0   19.5065   19.4471          0.0426
# 2010-08-27                    1.0   19.4945   19.4711          0.0554
# 2010-08-30                    1.0   19.4420   19.5091          0.0720
#
#             TSLA_MACD_Signal  TSLA_MACD  TSLA_SlowD  TSLA_SlowK  TSLA_RSI  \
# date
# 2010-08-24           -0.1039    -0.1483     65.1365     64.2590   43.3780
# 2010-08-25           -0.1001    -0.0853     67.5305     68.6417   46.1348
# 2010-08-26           -0.0895    -0.0469     64.7999     61.4989   45.6336
# 2010-08-27           -0.0757    -0.0203     66.1105     68.1908   45.4603
# 2010-08-30           -0.0576     0.0144     65.9999     68.3100   46.1916
#
#             TSLA_ADX  TSLA_CCI  TSLA_Real Upper Band  TSLA_Real Lower Band  \
# date
# 2010-08-24    4.5065  -21.9384               21.7879               17.3671
# 2010-08-25    4.5061   -3.2187               21.6903               17.3827
# 2010-08-26    4.6097   31.2156               21.6307               17.3823
# 2010-08-27    4.6664   17.5294               21.6114               17.3776
# 2010-08-30    4.8434   40.1607               21.4649               17.4191
#
#             TSLA_Real Middle Band  TSLA_Chaikin A/D    TSLA_OBV  \
# date
# 2010-08-24                19.5775     -5.397985e+06 -12174000.0
# 2010-08-25                19.5365     -4.951395e+06 -11670700.0
# 2010-08-26                19.5065     -5.190957e+06 -12104500.0
# 2010-08-27                19.4945     -5.154557e+06 -12484100.0
# 2010-08-30                19.4420     -5.230363e+06 -11751300.0
#
#             housing_index  conf_index  conf_index_SE  trade_value  \
# date
# 2010-08-24        147.552       63.87           3.48     102.4331
# 2010-08-25        147.552       63.87           3.48     102.9749
# 2010-08-26        147.552       63.87           3.48     102.9749
# 2010-08-27        147.552       63.87           3.48     102.9749
# 2010-08-30        147.552       63.87           3.48     102.9749
#
#             10 Yrs Rates  20-Yr Maturity Rate
# date
# 2010-08-24          3.17                 3.28
# 2010-08-25          3.20                 3.31
# 2010-08-26          3.15                 3.25
# 2010-08-27          3.31                 3.41
# 2010-08-30          3.19                 3.30

# %%
df.shape
# Out:
# (2124, 52)

# %%
df = tech_company_data('TSLA')
# Out:
# ###################################################################
#  Ticker:  TSLA
#  Last Refreshed:  2019-09-23 10:25:43
#  Data Retrieved:  Daily Time Series with Splits and Dividend Events
#  ###################################################################
# /home/ec2-user/SageMaker/fin_data.py:276: UserWarning: The latest value available for Housing Index is from January 2019.
#   warnings.warn("The latest value available for Housing Index is from January 2019.")

# %%
df.tail()
# Out:
#             TSLA_open  TSLA_high  TSLA_low  TSLA_close  TSLA_adjusted_close  \
# date
# 2019-01-25     294.39    298.519  289.5336      297.04               297.04
# 2019-01-28     292.91    297.460  287.7500      296.38               296.38
# 2019-01-29     295.27    298.557  291.8000      297.46               297.46
# 2019-01-30     300.45    309.000  298.4900      308.77               308.77
# 2019-01-31     301.00    311.564  294.0000      307.02               307.02
#
#             TSLA_volume  TSLA_dividend_amount  XLK_open  XLK_high  XLK_low  \
# date
# 2019-01-25    7249600.0                   0.0   65.5000    66.125  65.2600
# 2019-01-28    6423300.0                   0.0   64.9500    65.070  64.5100
# 2019-01-29    4621700.0                   0.0   65.1863    65.190  64.2500
# 2019-01-30   11250300.0                   0.0   65.4200    66.540  65.1298
# 2019-01-31   12569200.0                   0.0   66.0100    66.640  65.8000
#
#             XLK_close  XLK_adjusted_close  XLK_volume  XLK_dividend_amount  \
# date
# 2019-01-25      65.93             65.4863  10030800.0                  0.0
# 2019-01-28      65.05             64.6122   9662400.0                  0.0
# 2019-01-29      64.35             63.9169   8573900.0                  0.0
# 2019-01-30      66.35             65.9035  16995300.0                  0.0
# 2019-01-31      66.28             65.8339  18250900.0                  0.0
#
#             XLK_split_coefficient  vix_open  vix_high  vix_low  vix_close  \
# date
# 2019-01-25                    1.0     18.43     18.46    17.31      17.42
# 2019-01-28                    1.0     18.56     20.42    18.42      18.87
# 2019-01-29                    1.0     19.45     19.93    18.42      19.13
# 2019-01-30                    1.0     19.15     19.31    17.54      17.66
# 2019-01-31                    1.0     17.39     17.72    16.54      16.57
#
#             vix_adjusted_close  vix_volume  vix_dividend_amount  \
# date
# 2019-01-25               17.42         0.0                  0.0
# 2019-01-28               18.87         0.0                  0.0
# 2019-01-29               19.13         0.0                  0.0
# 2019-01-30               17.66         0.0                  0.0
# 2019-01-31               16.57         0.0                  0.0
#
#             vix_split_coefficient   SPX_open   SPX_high    SPX_low  SPX_close  \
# date
# 2019-01-25                    1.0  2657.4399  2672.3799  2657.3301  2664.7600
# 2019-01-28                    1.0  2644.9700  2644.9700  2624.0601  2643.8501
# 2019-01-29                    1.0  2644.8899  2650.9299  2631.0500  2640.0000
# 2019-01-30                    1.0  2653.6201  2690.4399  2648.3401  2681.0500
# 2019-01-31                    1.0  2685.4900  2708.9500  2678.6499  2704.1001
#
#             SPX_adjusted_close    SPX_volume  SPX_dividend_amount  \
# date
# 2019-01-25           2664.7600  3.814080e+09                  0.0
# 2019-01-28           2643.8501  3.612810e+09                  0.0
# 2019-01-29           2640.0000  3.504200e+09                  0.0
# 2019-01-30           2681.0500  3.857810e+09                  0.0
# 2019-01-31           2704.1001  4.917650e+09                  0.0
#
#             SPX_split_coefficient  TSLA_SMA  TSLA_EMA  TSLA_MACD_Signal  \
# date
# 2019-01-25                    1.0  323.0775  320.5019           -4.8971
# 2019-01-28                    1.0  322.0900  318.2045           -5.9604
# 2019-01-29                    1.0  320.2695  316.2289           -6.8785
# 2019-01-30                    1.0  319.0680  315.5185           -7.4612
# 2019-01-31                    1.0  318.9130  314.7091           -7.8142
#
#             TSLA_MACD_Hist  TSLA_MACD  TSLA_SlowK  TSLA_SlowD  TSLA_RSI  \
# date
# 2019-01-25         -4.6281    -9.5253     20.8115     12.5661   42.2487
# 2019-01-28         -4.2533   -10.2138     37.8597     23.0432   42.1009
# 2019-01-29         -3.6722   -10.5507     63.6522     40.7745   42.4477
# 2019-01-30         -2.3309    -9.7922     84.3569     61.9563   46.0115
# 2019-01-31         -1.4117    -9.2259     91.4844     79.8312   45.5521
#
#             TSLA_ADX  TSLA_CCI  TSLA_Real Upper Band  TSLA_Real Lower Band  \
# date
# 2019-01-25   14.5290  -99.7449              363.6159              282.5391
# 2019-01-28   15.0068  -94.8844              364.1894              279.9906
# 2019-01-29   15.4161  -78.3910              363.3122              277.2268
# 2019-01-30   15.3913  -42.5230              361.9859              276.1501
# 2019-01-31   15.4932  -45.5840              361.9811              275.8449
#
#             TSLA_Real Middle Band  TSLA_Chaikin A/D     TSLA_OBV  \
# date
# 2019-01-25               323.0775      2.407701e+08  292711900.0
# 2019-01-28               322.0900      2.457645e+08  286288600.0
# 2019-01-29               320.2695      2.488855e+08  290910300.0
# 2019-01-30               319.0680      2.596434e+08  302160600.0
# 2019-01-31               318.9130      2.657091e+08  289591400.0
#
#             housing_index  conf_index  conf_index_SE  trade_value  \
# date
# 2019-01-25        205.073       54.48           4.30     126.8701
# 2019-01-28        205.073       54.48           4.30     126.8701
# 2019-01-29        205.073       54.48           4.30     126.8701
# 2019-01-30        205.073       54.48           4.30     126.5041
# 2019-01-31        204.708       47.93           3.84     126.5041
#
#             10 Yrs Rates  20-Yr Maturity Rate
# date
# 2019-01-25          2.99                 2.92
# 2019-01-28          2.99                 2.92
# 2019-01-29          2.97                 2.90
# 2019-01-30          2.98                 2.90
# 2019-01-31          2.91                 2.83

# %%
# merge the df and df_fund data together

df_new = pd.merge(df, df_fund, on='date')

df_new.head()
# Out:
#             TSLA_open_x  TSLA_high_x  TSLA_low_x  TSLA_close_x  \
# date
# 2010-08-24        19.25       19.710       18.95         19.20
# 2010-08-25        19.16       19.980       18.56         19.90
# 2010-08-26        19.89       20.270       19.60         19.75
# 2010-08-27        19.75       19.865       19.50         19.70
# 2010-08-30        19.70       20.190       19.61         19.87
#
#             TSLA_adjusted_close_x  TSLA_volume_x  TSLA_dividend_amount_x  \
# date
# 2010-08-24                  19.20       673100.0                     0.0
# 2010-08-25                  19.90       503300.0                     0.0
# 2010-08-26                  19.75       433800.0                     0.0
# 2010-08-27                  19.70       379600.0                     0.0
# 2010-08-30                  19.87       732800.0                     0.0
#
#             XLK_open  XLK_high  XLK_low  XLK_close  XLK_adjusted_close  \
# date
# 2010-08-24     20.93    21.079    20.77      20.87             17.9672
# 2010-08-25     20.74    21.090    20.69      21.00             18.0791
# 2010-08-26     21.10    21.130    20.76      20.79             17.8983
# 2010-08-27     20.91    21.050    20.58      21.04             18.1136
# 2010-08-30     20.93    21.090    20.76      20.76             17.8725
#
#             XLK_volume  XLK_dividend_amount  XLK_split_coefficient  vix_open  \
# date
# 2010-08-24  10590300.0                  0.0                    1.0     27.91
# 2010-08-25  11052900.0                  0.0                    1.0     28.30
# 2010-08-26  10154700.0                  0.0                    1.0     26.45
# 2010-08-27  14991700.0                  0.0                    1.0     26.50
# 2010-08-30   7593500.0                  0.0                    1.0     25.88
#
#             vix_high  vix_low  vix_close  vix_adjusted_close  vix_volume  \
# date
# 2010-08-24     28.77    26.32      27.46               27.46         0.0
# 2010-08-25     28.92    26.46      26.70               26.70         0.0
# 2010-08-26     27.55    25.86      27.37               27.37         0.0
# 2010-08-27     28.11    24.41      24.45               24.45         0.0
# 2010-08-30     27.21    25.41      27.21               27.21         0.0
#
#             vix_dividend_amount  vix_split_coefficient  SPX_open  SPX_high  \
# date
# 2010-08-24                  0.0                    1.0   1063.20   1063.20
# 2010-08-25                  0.0                    1.0   1048.98   1059.38
# 2010-08-26                  0.0                    1.0   1056.28   1061.45
# 2010-08-27                  0.0                    1.0   1049.27   1065.21
# 2010-08-30                  0.0                    1.0   1062.90   1064.40
#
#               SPX_low  SPX_close  SPX_adjusted_close    SPX_volume  \
# date
# 2010-08-24  1046.6801    1051.87             1051.87  4.436330e+09
# 2010-08-25  1039.8300    1055.33             1055.33  4.360190e+09
# 2010-08-26  1045.4000    1047.22             1047.22  3.646710e+09
# 2010-08-27  1039.7000    1064.59             1064.59  4.102460e+09
# 2010-08-30  1048.7900    1048.92             1048.92  2.917990e+09
#
#             SPX_dividend_amount  SPX_split_coefficient  TSLA_SMA  TSLA_EMA  \
# date
# 2010-08-24                  0.0                    1.0   19.5775   19.3641
# 2010-08-25                  0.0                    1.0   19.5365   19.4152
# 2010-08-26                  0.0                    1.0   19.5065   19.4471
# 2010-08-27                  0.0                    1.0   19.4945   19.4711
# 2010-08-30                  0.0                    1.0   19.4420   19.5091
#
#             TSLA_MACD_Signal  TSLA_MACD_Hist  TSLA_MACD  TSLA_SlowK  \
# date
# 2010-08-24           -0.1039         -0.0444    -0.1483     64.2590
# 2010-08-25           -0.1001          0.0149    -0.0853     68.6417
# 2010-08-26           -0.0895          0.0426    -0.0469     61.4989
# 2010-08-27           -0.0757          0.0554    -0.0203     68.1908
# 2010-08-30           -0.0576          0.0720     0.0144     68.3100
#
#             TSLA_SlowD  TSLA_RSI  TSLA_ADX  TSLA_CCI  TSLA_Real Upper Band  \
# date
# 2010-08-24     65.1365   43.3780    4.5065  -21.9384               21.7879
# 2010-08-25     67.5305   46.1348    4.5061   -3.2187               21.6903
# 2010-08-26     64.7999   45.6336    4.6097   31.2156               21.6307
# 2010-08-27     66.1105   45.4603    4.6664   17.5294               21.6114
# 2010-08-30     65.9999   46.1916    4.8434   40.1607               21.4649
#
#             TSLA_Real Lower Band  TSLA_Real Middle Band  TSLA_Chaikin A/D  \
# date
# 2010-08-24               17.3671                19.5775     -5.397985e+06
# 2010-08-25               17.3827                19.5365     -4.951395e+06
# 2010-08-26               17.3823                19.5065     -5.190957e+06
# 2010-08-27               17.3776                19.4945     -5.154557e+06
# 2010-08-30               17.4191                19.4420     -5.230363e+06
#
#               TSLA_OBV  housing_index  conf_index  conf_index_SE  trade_value  \
# date
# 2010-08-24 -12174000.0        147.552       63.87           3.48     102.4331
# 2010-08-25 -11670700.0        147.552       63.87           3.48     102.9749
# 2010-08-26 -12104500.0        147.552       63.87           3.48     102.9749
# 2010-08-27 -12484100.0        147.552       63.87           3.48     102.9749
# 2010-08-30 -11751300.0        147.552       63.87           3.48     102.9749
#
#             10 Yrs Rates  20-Yr Maturity Rate  TSLA_open_y  TSLA_high_y  \
# date
# 2010-08-24          3.17                 3.28        19.25       19.710
# 2010-08-25          3.20                 3.31        19.16       19.980
# 2010-08-26          3.15                 3.25        19.89       20.270
# 2010-08-27          3.31                 3.41        19.75       19.865
# 2010-08-30          3.19                 3.30        19.70       20.190
#
#             TSLA_low_y  TSLA_close_y  TSLA_adjusted_close_y  TSLA_volume_y  \
# date
# 2010-08-24       18.95         19.20                  19.20       673100.0
# 2010-08-25       18.56         19.90                  19.90       503300.0
# 2010-08-26       19.60         19.75                  19.75       433800.0
# 2010-08-27       19.50         19.70                  19.70       379600.0
# 2010-08-30       19.61         19.87                  19.87       732800.0
#
#             TSLA_dividend_amount_y  TSLA_operatingrevenue  TSLA_totalrevenue  \
# date
# 2010-08-24                     0.0             31241000.0         31241000.0
# 2010-08-25                     0.0             31241000.0         31241000.0
# 2010-08-26                     0.0             31241000.0         31241000.0
# 2010-08-27                     0.0             31241000.0         31241000.0
# 2010-08-30                     0.0             31241000.0         31241000.0
#
#             TSLA_netincome  TSLA_totaloperatingexpenses  \
# date
# 2010-08-24     -34935000.0                   47130000.0
# 2010-08-25     -34935000.0                   47130000.0
# 2010-08-26     -34935000.0                   47130000.0
# 2010-08-27     -34935000.0                   47130000.0
# 2010-08-30     -34935000.0                   47130000.0
#
#             TSLA_totalgrossprofit  TSLA_totaloperatingincome  \
# date
# 2010-08-24              9296000.0                -37834000.0
# 2010-08-25              9296000.0                -37834000.0
# 2010-08-26              9296000.0                -37834000.0
# 2010-08-27              9296000.0                -37834000.0
# 2010-08-30              9296000.0                -37834000.0
#
#             TSLA_totalpretaxincome  TSLA_weightedavebasicdilutedsharesos  \
# date
# 2010-08-24             -34852000.0                            92270721.0
# 2010-08-25             -34852000.0                            92270721.0
# 2010-08-26             -34852000.0                            92270721.0
# 2010-08-27             -34852000.0                            92270721.0
# 2010-08-30             -34852000.0                            92270721.0
#
#             TSLA_cashdividendspershare  TSLA_totalcostofrevenue
# date
# 2010-08-24                         0.0               21945000.0
# 2010-08-25                         0.0               21945000.0
# 2010-08-26                         0.0               21945000.0
# 2010-08-27                         0.0               21945000.0
# 2010-08-30                         0.0               21945000.0

# %% [markdown]
# Finally, the new dataframe has all the columns and indicators that we were initially planning on using. Let's move forward from here.

# %%
print('There are {} number of days in the dataset.'.format(df_new.shape[0]))
# Out:
# There are 2124 number of days in the dataset.

# %% [markdown]
# ### Target & Split
#
# We will use the adjusted close shift by 1 day for now.
#
# We will then split the dataframe into X and y and further training and testing sets.

# %%
# df['percent_change'] = ((df['TSLA_close'].shift(-1) - df['TSLA close']) / (df['TSLA close']))*100

# %%
#df['percent_change'].head()

# %%
df_new.head()
# Out:
#             TSLA_open_x  TSLA_high_x  TSLA_low_x  TSLA_close_x  \
# date
# 2010-08-24        19.25       19.710       18.95         19.20
# 2010-08-25        19.16       19.980       18.56         19.90
# 2010-08-26        19.89       20.270       19.60         19.75
# 2010-08-27        19.75       19.865       19.50         19.70
# 2010-08-30        19.70       20.190       19.61         19.87
#
#             TSLA_adjusted_close_x  TSLA_volume_x  TSLA_dividend_amount_x  \
# date
# 2010-08-24                  19.20       673100.0                     0.0
# 2010-08-25                  19.90       503300.0                     0.0
# 2010-08-26                  19.75       433800.0                     0.0
# 2010-08-27                  19.70       379600.0                     0.0
# 2010-08-30                  19.87       732800.0                     0.0
#
#             XLK_open  XLK_high  XLK_low  XLK_close  XLK_adjusted_close  \
# date
# 2010-08-24     20.93    21.079    20.77      20.87             17.9672
# 2010-08-25     20.74    21.090    20.69      21.00             18.0791
# 2010-08-26     21.10    21.130    20.76      20.79             17.8983
# 2010-08-27     20.91    21.050    20.58      21.04             18.1136
# 2010-08-30     20.93    21.090    20.76      20.76             17.8725
#
#             XLK_volume  XLK_dividend_amount  XLK_split_coefficient  vix_open  \
# date
# 2010-08-24  10590300.0                  0.0                    1.0     27.91
# 2010-08-25  11052900.0                  0.0                    1.0     28.30
# 2010-08-26  10154700.0                  0.0                    1.0     26.45
# 2010-08-27  14991700.0                  0.0                    1.0     26.50
# 2010-08-30   7593500.0                  0.0                    1.0     25.88
#
#             vix_high  vix_low  vix_close  vix_adjusted_close  vix_volume  \
# date
# 2010-08-24     28.77    26.32      27.46               27.46         0.0
# 2010-08-25     28.92    26.46      26.70               26.70         0.0
# 2010-08-26     27.55    25.86      27.37               27.37         0.0
# 2010-08-27     28.11    24.41      24.45               24.45         0.0
# 2010-08-30     27.21    25.41      27.21               27.21         0.0
#
#             vix_dividend_amount  vix_split_coefficient  SPX_open  SPX_high  \
# date
# 2010-08-24                  0.0                    1.0   1063.20   1063.20
# 2010-08-25                  0.0                    1.0   1048.98   1059.38
# 2010-08-26                  0.0                    1.0   1056.28   1061.45
# 2010-08-27                  0.0                    1.0   1049.27   1065.21
# 2010-08-30                  0.0                    1.0   1062.90   1064.40
#
#               SPX_low  SPX_close  SPX_adjusted_close    SPX_volume  \
# date
# 2010-08-24  1046.6801    1051.87             1051.87  4.436330e+09
# 2010-08-25  1039.8300    1055.33             1055.33  4.360190e+09
# 2010-08-26  1045.4000    1047.22             1047.22  3.646710e+09
# 2010-08-27  1039.7000    1064.59             1064.59  4.102460e+09
# 2010-08-30  1048.7900    1048.92             1048.92  2.917990e+09
#
#             SPX_dividend_amount  SPX_split_coefficient  TSLA_SMA  TSLA_EMA  \
# date
# 2010-08-24                  0.0                    1.0   19.5775   19.3641
# 2010-08-25                  0.0                    1.0   19.5365   19.4152
# 2010-08-26                  0.0                    1.0   19.5065   19.4471
# 2010-08-27                  0.0                    1.0   19.4945   19.4711
# 2010-08-30                  0.0                    1.0   19.4420   19.5091
#
#             TSLA_MACD_Signal  TSLA_MACD_Hist  TSLA_MACD  TSLA_SlowK  \
# date
# 2010-08-24           -0.1039         -0.0444    -0.1483     64.2590
# 2010-08-25           -0.1001          0.0149    -0.0853     68.6417
# 2010-08-26           -0.0895          0.0426    -0.0469     61.4989
# 2010-08-27           -0.0757          0.0554    -0.0203     68.1908
# 2010-08-30           -0.0576          0.0720     0.0144     68.3100
#
#             TSLA_SlowD  TSLA_RSI  TSLA_ADX  TSLA_CCI  TSLA_Real Upper Band  \
# date
# 2010-08-24     65.1365   43.3780    4.5065  -21.9384               21.7879
# 2010-08-25     67.5305   46.1348    4.5061   -3.2187               21.6903
# 2010-08-26     64.7999   45.6336    4.6097   31.2156               21.6307
# 2010-08-27     66.1105   45.4603    4.6664   17.5294               21.6114
# 2010-08-30     65.9999   46.1916    4.8434   40.1607               21.4649
#
#             TSLA_Real Lower Band  TSLA_Real Middle Band  TSLA_Chaikin A/D  \
# date
# 2010-08-24               17.3671                19.5775     -5.397985e+06
# 2010-08-25               17.3827                19.5365     -4.951395e+06
# 2010-08-26               17.3823                19.5065     -5.190957e+06
# 2010-08-27               17.3776                19.4945     -5.154557e+06
# 2010-08-30               17.4191                19.4420     -5.230363e+06
#
#               TSLA_OBV  housing_index  conf_index  conf_index_SE  trade_value  \
# date
# 2010-08-24 -12174000.0        147.552       63.87           3.48     102.4331
# 2010-08-25 -11670700.0        147.552       63.87           3.48     102.9749
# 2010-08-26 -12104500.0        147.552       63.87           3.48     102.9749
# 2010-08-27 -12484100.0        147.552       63.87           3.48     102.9749
# 2010-08-30 -11751300.0        147.552       63.87           3.48     102.9749
#
#             10 Yrs Rates  20-Yr Maturity Rate  TSLA_open_y  TSLA_high_y  \
# date
# 2010-08-24          3.17                 3.28        19.25       19.710
# 2010-08-25          3.20                 3.31        19.16       19.980
# 2010-08-26          3.15                 3.25        19.89       20.270
# 2010-08-27          3.31                 3.41        19.75       19.865
# 2010-08-30          3.19                 3.30        19.70       20.190
#
#             TSLA_low_y  TSLA_close_y  TSLA_adjusted_close_y  TSLA_volume_y  \
# date
# 2010-08-24       18.95         19.20                  19.20       673100.0
# 2010-08-25       18.56         19.90                  19.90       503300.0
# 2010-08-26       19.60         19.75                  19.75       433800.0
# 2010-08-27       19.50         19.70                  19.70       379600.0
# 2010-08-30       19.61         19.87                  19.87       732800.0
#
#             TSLA_dividend_amount_y  TSLA_operatingrevenue  TSLA_totalrevenue  \
# date
# 2010-08-24                     0.0             31241000.0         31241000.0
# 2010-08-25                     0.0             31241000.0         31241000.0
# 2010-08-26                     0.0             31241000.0         31241000.0
# 2010-08-27                     0.0             31241000.0         31241000.0
# 2010-08-30                     0.0             31241000.0         31241000.0
#
#             TSLA_netincome  TSLA_totaloperatingexpenses  \
# date
# 2010-08-24     -34935000.0                   47130000.0
# 2010-08-25     -34935000.0                   47130000.0
# 2010-08-26     -34935000.0                   47130000.0
# 2010-08-27     -34935000.0                   47130000.0
# 2010-08-30     -34935000.0                   47130000.0
#
#             TSLA_totalgrossprofit  TSLA_totaloperatingincome  \
# date
# 2010-08-24              9296000.0                -37834000.0
# 2010-08-25              9296000.0                -37834000.0
# 2010-08-26              9296000.0                -37834000.0
# 2010-08-27              9296000.0                -37834000.0
# 2010-08-30              9296000.0                -37834000.0
#
#             TSLA_totalpretaxincome  TSLA_weightedavebasicdilutedsharesos  \
# date
# 2010-08-24             -34852000.0                            92270721.0
# 2010-08-25             -34852000.0                            92270721.0
# 2010-08-26             -34852000.0                            92270721.0
# 2010-08-27             -34852000.0                            92270721.0
# 2010-08-30             -34852000.0                            92270721.0
#
#             TSLA_cashdividendspershare  TSLA_totalcostofrevenue
# date
# 2010-08-24                         0.0               21945000.0
# 2010-08-25                         0.0               21945000.0
# 2010-08-26                         0.0               21945000.0
# 2010-08-27                         0.0               21945000.0
# 2010-08-30                         0.0               21945000.0

# %%
df_new['target'] = ((df_new['TSLA_close_x'].shift(-1)))
                     # - df_new['TSLA close_x']) / (df_new['TSLA close_x']))*100

# %%
df_new['target'].head()
# Out:
# date
# 2010-08-24    19.90
# 2010-08-25    19.75
# 2010-08-26    19.70
# 2010-08-27    19.87
# 2010-08-30    19.48
# Name: target, dtype: float64

# %%
df_new.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['TSLA_open_x', 'TSLA_high_x', 'TSLA_low_x', 'TSLA_close_x',
#        'TSLA_adjusted_close_x', 'TSLA_volume_x', 'TSLA_dividend_amount_x',
#        'XLK_open', 'XLK_high', 'XLK_low', 'XLK_close', 'XLK_adjusted_close',
#        'XLK_volume', 'XLK_dividend_amount', 'XLK_split_coefficient',
#        'vix_open', 'vix_high', 'vix_low', 'vix_close', 'vix_adjusted_close',
#        'vix_volume', 'vix_dividend_amount', 'vix_split_coefficient',
#        'SPX_open', 'SPX_high', 'SPX_low', 'SPX_close', 'SPX_adjusted_close',
#        'SPX_volume', 'SPX_dividend_amount', 'SPX_split_coefficient',
#        'TSLA_SMA', 'TSLA_EMA', 'TSLA_MACD_Signal', 'TSLA_MACD_Hist',
#        'TSLA_MACD', 'TSLA_SlowK', 'TSLA_SlowD', 'TSLA_RSI', 'TSLA_ADX',
#        'TSLA_CCI', 'TSLA_Real Upper Band', 'TSLA_Real Lower Band',
#        'TSLA_Real Middle Band', 'TSLA_Chaikin A/D', 'TSLA_OBV',
#        'housing_index', 'conf_index', 'conf_index_SE', 'trade_value',
#        '10 Yrs Rates', '20-Yr Maturity Rate', 'TSLA_open_y', 'TSLA_high_y',
#        'TSLA_low_y', 'TSLA_close_y', 'TSLA_adjusted_close_y', 'TSLA_volume_y',
#        'TSLA_dividend_amount_y', 'TSLA_operatingrevenue', 'TSLA_totalrevenue',
#        'TSLA_netincome', 'TSLA_totaloperatingexpenses',
#        'TSLA_totalgrossprofit', 'TSLA_totaloperatingincome',
#        'TSLA_totalpretaxincome', 'TSLA_weightedavebasicdilutedsharesos',
#        'TSLA_cashdividendspershare', 'TSLA_totalcostofrevenue', 'target'],
#       dtype='object')>

# %%
df_new.head()
# Out:
#             TSLA_open_x  TSLA_high_x  TSLA_low_x  TSLA_close_x  \
# date
# 2010-08-24        19.25       19.710       18.95         19.20
# 2010-08-25        19.16       19.980       18.56         19.90
# 2010-08-26        19.89       20.270       19.60         19.75
# 2010-08-27        19.75       19.865       19.50         19.70
# 2010-08-30        19.70       20.190       19.61         19.87
#
#             TSLA_adjusted_close_x  TSLA_volume_x  TSLA_dividend_amount_x  \
# date
# 2010-08-24                  19.20       673100.0                     0.0
# 2010-08-25                  19.90       503300.0                     0.0
# 2010-08-26                  19.75       433800.0                     0.0
# 2010-08-27                  19.70       379600.0                     0.0
# 2010-08-30                  19.87       732800.0                     0.0
#
#             XLK_open  XLK_high  XLK_low  XLK_close  XLK_adjusted_close  \
# date
# 2010-08-24     20.93    21.079    20.77      20.87             17.9672
# 2010-08-25     20.74    21.090    20.69      21.00             18.0791
# 2010-08-26     21.10    21.130    20.76      20.79             17.8983
# 2010-08-27     20.91    21.050    20.58      21.04             18.1136
# 2010-08-30     20.93    21.090    20.76      20.76             17.8725
#
#             XLK_volume  XLK_dividend_amount  XLK_split_coefficient  vix_open  \
# date
# 2010-08-24  10590300.0                  0.0                    1.0     27.91
# 2010-08-25  11052900.0                  0.0                    1.0     28.30
# 2010-08-26  10154700.0                  0.0                    1.0     26.45
# 2010-08-27  14991700.0                  0.0                    1.0     26.50
# 2010-08-30   7593500.0                  0.0                    1.0     25.88
#
#             vix_high  vix_low  vix_close  vix_adjusted_close  vix_volume  \
# date
# 2010-08-24     28.77    26.32      27.46               27.46         0.0
# 2010-08-25     28.92    26.46      26.70               26.70         0.0
# 2010-08-26     27.55    25.86      27.37               27.37         0.0
# 2010-08-27     28.11    24.41      24.45               24.45         0.0
# 2010-08-30     27.21    25.41      27.21               27.21         0.0
#
#             vix_dividend_amount  vix_split_coefficient  SPX_open  SPX_high  \
# date
# 2010-08-24                  0.0                    1.0   1063.20   1063.20
# 2010-08-25                  0.0                    1.0   1048.98   1059.38
# 2010-08-26                  0.0                    1.0   1056.28   1061.45
# 2010-08-27                  0.0                    1.0   1049.27   1065.21
# 2010-08-30                  0.0                    1.0   1062.90   1064.40
#
#               SPX_low  SPX_close  SPX_adjusted_close    SPX_volume  \
# date
# 2010-08-24  1046.6801    1051.87             1051.87  4.436330e+09
# 2010-08-25  1039.8300    1055.33             1055.33  4.360190e+09
# 2010-08-26  1045.4000    1047.22             1047.22  3.646710e+09
# 2010-08-27  1039.7000    1064.59             1064.59  4.102460e+09
# 2010-08-30  1048.7900    1048.92             1048.92  2.917990e+09
#
#             SPX_dividend_amount  SPX_split_coefficient  TSLA_SMA  TSLA_EMA  \
# date
# 2010-08-24                  0.0                    1.0   19.5775   19.3641
# 2010-08-25                  0.0                    1.0   19.5365   19.4152
# 2010-08-26                  0.0                    1.0   19.5065   19.4471
# 2010-08-27                  0.0                    1.0   19.4945   19.4711
# 2010-08-30                  0.0                    1.0   19.4420   19.5091
#
#             TSLA_MACD_Signal  TSLA_MACD_Hist  TSLA_MACD  TSLA_SlowK  \
# date
# 2010-08-24           -0.1039         -0.0444    -0.1483     64.2590
# 2010-08-25           -0.1001          0.0149    -0.0853     68.6417
# 2010-08-26           -0.0895          0.0426    -0.0469     61.4989
# 2010-08-27           -0.0757          0.0554    -0.0203     68.1908
# 2010-08-30           -0.0576          0.0720     0.0144     68.3100
#
#             TSLA_SlowD  TSLA_RSI  TSLA_ADX  TSLA_CCI  TSLA_Real Upper Band  \
# date
# 2010-08-24     65.1365   43.3780    4.5065  -21.9384               21.7879
# 2010-08-25     67.5305   46.1348    4.5061   -3.2187               21.6903
# 2010-08-26     64.7999   45.6336    4.6097   31.2156               21.6307
# 2010-08-27     66.1105   45.4603    4.6664   17.5294               21.6114
# 2010-08-30     65.9999   46.1916    4.8434   40.1607               21.4649
#
#             TSLA_Real Lower Band  TSLA_Real Middle Band  TSLA_Chaikin A/D  \
# date
# 2010-08-24               17.3671                19.5775     -5.397985e+06
# 2010-08-25               17.3827                19.5365     -4.951395e+06
# 2010-08-26               17.3823                19.5065     -5.190957e+06
# 2010-08-27               17.3776                19.4945     -5.154557e+06
# 2010-08-30               17.4191                19.4420     -5.230363e+06
#
#               TSLA_OBV  housing_index  conf_index  conf_index_SE  trade_value  \
# date
# 2010-08-24 -12174000.0        147.552       63.87           3.48     102.4331
# 2010-08-25 -11670700.0        147.552       63.87           3.48     102.9749
# 2010-08-26 -12104500.0        147.552       63.87           3.48     102.9749
# 2010-08-27 -12484100.0        147.552       63.87           3.48     102.9749
# 2010-08-30 -11751300.0        147.552       63.87           3.48     102.9749
#
#             10 Yrs Rates  20-Yr Maturity Rate  TSLA_open_y  TSLA_high_y  \
# date
# 2010-08-24          3.17                 3.28        19.25       19.710
# 2010-08-25          3.20                 3.31        19.16       19.980
# 2010-08-26          3.15                 3.25        19.89       20.270
# 2010-08-27          3.31                 3.41        19.75       19.865
# 2010-08-30          3.19                 3.30        19.70       20.190
#
#             TSLA_low_y  TSLA_close_y  TSLA_adjusted_close_y  TSLA_volume_y  \
# date
# 2010-08-24       18.95         19.20                  19.20       673100.0
# 2010-08-25       18.56         19.90                  19.90       503300.0
# 2010-08-26       19.60         19.75                  19.75       433800.0
# 2010-08-27       19.50         19.70                  19.70       379600.0
# 2010-08-30       19.61         19.87                  19.87       732800.0
#
#             TSLA_dividend_amount_y  TSLA_operatingrevenue  TSLA_totalrevenue  \
# date
# 2010-08-24                     0.0             31241000.0         31241000.0
# 2010-08-25                     0.0             31241000.0         31241000.0
# 2010-08-26                     0.0             31241000.0         31241000.0
# 2010-08-27                     0.0             31241000.0         31241000.0
# 2010-08-30                     0.0             31241000.0         31241000.0
#
#             TSLA_netincome  TSLA_totaloperatingexpenses  \
# date
# 2010-08-24     -34935000.0                   47130000.0
# 2010-08-25     -34935000.0                   47130000.0
# 2010-08-26     -34935000.0                   47130000.0
# 2010-08-27     -34935000.0                   47130000.0
# 2010-08-30     -34935000.0                   47130000.0
#
#             TSLA_totalgrossprofit  TSLA_totaloperatingincome  \
# date
# 2010-08-24              9296000.0                -37834000.0
# 2010-08-25              9296000.0                -37834000.0
# 2010-08-26              9296000.0                -37834000.0
# 2010-08-27              9296000.0                -37834000.0
# 2010-08-30              9296000.0                -37834000.0
#
#             TSLA_totalpretaxincome  TSLA_weightedavebasicdilutedsharesos  \
# date
# 2010-08-24             -34852000.0                            92270721.0
# 2010-08-25             -34852000.0                            92270721.0
# 2010-08-26             -34852000.0                            92270721.0
# 2010-08-27             -34852000.0                            92270721.0
# 2010-08-30             -34852000.0                            92270721.0
#
#             TSLA_cashdividendspershare  TSLA_totalcostofrevenue  target
# date
# 2010-08-24                         0.0               21945000.0   19.90
# 2010-08-25                         0.0               21945000.0   19.75
# 2010-08-26                         0.0               21945000.0   19.70
# 2010-08-27                         0.0               21945000.0   19.87
# 2010-08-30                         0.0               21945000.0   19.48

# %%
df_new.shape
# Out:
# (2124, 70)

# %% [markdown]
# df.columns

# %%
df_new.columns = ['TSLA open', 'TSLA high', 'TSLA low', 'TSLA close',
       'TSLA adj_close', 'TSLA_vol', 'TSLA_div',
       'XLK open', 'XLK high', 'XLK low',
       'XLK close', 'XLK adj_close', 'XLK_vol',
       'XLK_div', 'vix open',
       'vix high', 'vix low', 'vix close', 'vix adj_close',
       'vix_vol', 'vix_div', 'vix_coef',
       'SPX open', 'SPX high', 'SPX low', 'SPX close', 'SPX adj_close',
       'SPX vol', 'SPX_div', 'SPX_coef',
       'TSLA_SMA', 'TSLA_EMA', 'TSLA_MACD_Signal', 'TSLA_MACD_Hist',
       'TSLA_MACD', 'TSLA_SlowD', 'TSLA_SlowK', 'TSLA_RSI', 'TSLA_ADX',
       'TSLA_CCI', 'TSLA_Real Middle Band', 'TSLA_Real Upper Band',
       'TSLA_Real Lower Band', 'TSLA_Chaikin A/D', 'TSLA_OBV', 'housing_index',
       'conf_index', 'conf_index_SE', 'trade_value', '10 Yrs Rates',
       '20-Yr Maturity Rate', 'TSLA open_y', 'TSLA high_y', 'TSLA low_y',
       'TSLA close_y', '5. adjusted close', '6. volume', '7. dividend amount',
       '8. split coefficient', 'TSLA_operatingrevenue', 'TSLA_totalrevenue',
       'TSLA_netincome', 'TSLA_totaloperatingexpenses',
       'TSLA_totalgrossprofit', 'TSLA_totaloperatingincome', "totalpretaxincome", "weightedavebasicdilutedsharesos", "cashdividendspershare", "totalcostofrevenue", 'target']

# %%
df_new.head()
# Out:
#             TSLA open  TSLA high  TSLA low  TSLA close  TSLA adj_close  \
# date
# 2010-08-24      19.25     19.710     18.95       19.20           19.20
# 2010-08-25      19.16     19.980     18.56       19.90           19.90
# 2010-08-26      19.89     20.270     19.60       19.75           19.75
# 2010-08-27      19.75     19.865     19.50       19.70           19.70
# 2010-08-30      19.70     20.190     19.61       19.87           19.87
#
#             TSLA_vol  TSLA_div  XLK open  XLK high  XLK low  XLK close  \
# date
# 2010-08-24  673100.0       0.0     20.93    21.079    20.77      20.87
# 2010-08-25  503300.0       0.0     20.74    21.090    20.69      21.00
# 2010-08-26  433800.0       0.0     21.10    21.130    20.76      20.79
# 2010-08-27  379600.0       0.0     20.91    21.050    20.58      21.04
# 2010-08-30  732800.0       0.0     20.93    21.090    20.76      20.76
#
#             XLK adj_close     XLK_vol  XLK_div  vix open  vix high  vix low  \
# date
# 2010-08-24        17.9672  10590300.0      0.0       1.0     27.91    28.77
# 2010-08-25        18.0791  11052900.0      0.0       1.0     28.30    28.92
# 2010-08-26        17.8983  10154700.0      0.0       1.0     26.45    27.55
# 2010-08-27        18.1136  14991700.0      0.0       1.0     26.50    28.11
# 2010-08-30        17.8725   7593500.0      0.0       1.0     25.88    27.21
#
#             vix close  vix adj_close  vix_vol  vix_div  vix_coef  SPX open  \
# date
# 2010-08-24      26.32          27.46    27.46      0.0       0.0       1.0
# 2010-08-25      26.46          26.70    26.70      0.0       0.0       1.0
# 2010-08-26      25.86          27.37    27.37      0.0       0.0       1.0
# 2010-08-27      24.41          24.45    24.45      0.0       0.0       1.0
# 2010-08-30      25.41          27.21    27.21      0.0       0.0       1.0
#
#             SPX high  SPX low  SPX close  SPX adj_close  SPX vol  \
# date
# 2010-08-24   1063.20  1063.20  1046.6801        1051.87  1051.87
# 2010-08-25   1048.98  1059.38  1039.8300        1055.33  1055.33
# 2010-08-26   1056.28  1061.45  1045.4000        1047.22  1047.22
# 2010-08-27   1049.27  1065.21  1039.7000        1064.59  1064.59
# 2010-08-30   1062.90  1064.40  1048.7900        1048.92  1048.92
#
#                  SPX_div  SPX_coef  TSLA_SMA  TSLA_EMA  TSLA_MACD_Signal  \
# date
# 2010-08-24  4.436330e+09       0.0       1.0   19.5775           19.3641
# 2010-08-25  4.360190e+09       0.0       1.0   19.5365           19.4152
# 2010-08-26  3.646710e+09       0.0       1.0   19.5065           19.4471
# 2010-08-27  4.102460e+09       0.0       1.0   19.4945           19.4711
# 2010-08-30  2.917990e+09       0.0       1.0   19.4420           19.5091
#
#             TSLA_MACD_Hist  TSLA_MACD  TSLA_SlowD  TSLA_SlowK  TSLA_RSI  \
# date
# 2010-08-24         -0.1039    -0.0444     -0.1483     64.2590   65.1365
# 2010-08-25         -0.1001     0.0149     -0.0853     68.6417   67.5305
# 2010-08-26         -0.0895     0.0426     -0.0469     61.4989   64.7999
# 2010-08-27         -0.0757     0.0554     -0.0203     68.1908   66.1105
# 2010-08-30         -0.0576     0.0720      0.0144     68.3100   65.9999
#
#             TSLA_ADX  TSLA_CCI  TSLA_Real Middle Band  TSLA_Real Upper Band  \
# date
# 2010-08-24   43.3780    4.5065               -21.9384               21.7879
# 2010-08-25   46.1348    4.5061                -3.2187               21.6903
# 2010-08-26   45.6336    4.6097                31.2156               21.6307
# 2010-08-27   45.4603    4.6664                17.5294               21.6114
# 2010-08-30   46.1916    4.8434                40.1607               21.4649
#
#             TSLA_Real Lower Band  TSLA_Chaikin A/D      TSLA_OBV  \
# date
# 2010-08-24               17.3671           19.5775 -5.397985e+06
# 2010-08-25               17.3827           19.5365 -4.951395e+06
# 2010-08-26               17.3823           19.5065 -5.190957e+06
# 2010-08-27               17.3776           19.4945 -5.154557e+06
# 2010-08-30               17.4191           19.4420 -5.230363e+06
#
#             housing_index  conf_index  conf_index_SE  trade_value  \
# date
# 2010-08-24    -12174000.0     147.552          63.87         3.48
# 2010-08-25    -11670700.0     147.552          63.87         3.48
# 2010-08-26    -12104500.0     147.552          63.87         3.48
# 2010-08-27    -12484100.0     147.552          63.87         3.48
# 2010-08-30    -11751300.0     147.552          63.87         3.48
#
#             10 Yrs Rates  20-Yr Maturity Rate  TSLA open_y  TSLA high_y  \
# date
# 2010-08-24      102.4331                 3.17         3.28        19.25
# 2010-08-25      102.9749                 3.20         3.31        19.16
# 2010-08-26      102.9749                 3.15         3.25        19.89
# 2010-08-27      102.9749                 3.31         3.41        19.75
# 2010-08-30      102.9749                 3.19         3.30        19.70
#
#             TSLA low_y  TSLA close_y  5. adjusted close  6. volume  \
# date
# 2010-08-24      19.710         18.95              19.20      19.20
# 2010-08-25      19.980         18.56              19.90      19.90
# 2010-08-26      20.270         19.60              19.75      19.75
# 2010-08-27      19.865         19.50              19.70      19.70
# 2010-08-30      20.190         19.61              19.87      19.87
#
#             7. dividend amount  8. split coefficient  TSLA_operatingrevenue  \
# date
# 2010-08-24            673100.0                   0.0             31241000.0
# 2010-08-25            503300.0                   0.0             31241000.0
# 2010-08-26            433800.0                   0.0             31241000.0
# 2010-08-27            379600.0                   0.0             31241000.0
# 2010-08-30            732800.0                   0.0             31241000.0
#
#             TSLA_totalrevenue  TSLA_netincome  TSLA_totaloperatingexpenses  \
# date
# 2010-08-24         31241000.0     -34935000.0                   47130000.0
# 2010-08-25         31241000.0     -34935000.0                   47130000.0
# 2010-08-26         31241000.0     -34935000.0                   47130000.0
# 2010-08-27         31241000.0     -34935000.0                   47130000.0
# 2010-08-30         31241000.0     -34935000.0                   47130000.0
#
#             TSLA_totalgrossprofit  TSLA_totaloperatingincome  \
# date
# 2010-08-24              9296000.0                -37834000.0
# 2010-08-25              9296000.0                -37834000.0
# 2010-08-26              9296000.0                -37834000.0
# 2010-08-27              9296000.0                -37834000.0
# 2010-08-30              9296000.0                -37834000.0
#
#             totalpretaxincome  weightedavebasicdilutedsharesos  \
# date
# 2010-08-24        -34852000.0                       92270721.0
# 2010-08-25        -34852000.0                       92270721.0
# 2010-08-26        -34852000.0                       92270721.0
# 2010-08-27        -34852000.0                       92270721.0
# 2010-08-30        -34852000.0                       92270721.0
#
#             cashdividendspershare  totalcostofrevenue  target
# date
# 2010-08-24                    0.0          21945000.0   19.90
# 2010-08-25                    0.0          21945000.0   19.75
# 2010-08-26                    0.0          21945000.0   19.70
# 2010-08-27                    0.0          21945000.0   19.87
# 2010-08-30                    0.0          21945000.0   19.48

# %%
X = df_new.drop(columns=['target', 'TSLA close', 'TSLA adj_close', 'TSLA open', 'TSLA high', 'TSLA low'])
y = df_new[['target']].values

# %%
X.shape, y.shape
# Out:
# ((2124, 64), (2124, 1))

# %%
def prep_data(train_cut, val_cut, X=X, y=y):
    
    scaler = MinMaxScaler()
    scaler.fit(X)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                        train_size=train_cut, 
                                                        shuffle=False)

    X_test, X_val, y_test, y_val = train_test_split(X_test, y_test,
                                                    train_size=val_cut,
                                                    shuffle=False)
    
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    X_val = scaler.transform(X_val)
    
    return X_train, X_test, X_val, y_train, y_test, y_val

# %%
X_train, X_test, X_val, y_train, y_test, y_val = prep_data(train_cut=0.8, val_cut= 0.6)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1699, 64), (255, 64), (1699, 1), (255, 1), (170, 64), (170, 1))

# %% [markdown]
# ##### Time Series Generator

# %%
train_data_generator = TimeseriesGenerator(X_train, y_train, 
                                           length=15,
                                           sampling_rate=1, 
                                           stride=1, 
                                           batch_size=6)

test_data_generator = TimeseriesGenerator(X_test, y_test, 
                                          length=15, 
                                          sampling_rate=1,
                                          stride=1,
                                          batch_size=6)

val_data_generator = TimeseriesGenerator(X_val, y_val, 
                                          length=15, 
                                          sampling_rate=1,
                                          stride=1,
                                          batch_size=6)

# %% [markdown]
# ### Model

# %%
# imports

from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import h5py

# %%
model = Sequential()
model.add(LSTM(256, activation='relu', 
               return_sequences=True, 
               input_shape=(train_data_generator.length, 
                            X_train.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(144, return_sequences=True,
               activation='relu'))
model.add(Dropout(0.2))
model.add(LSTM(72, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0923 14:26:05.983554 140684055553856 deprecation_wrapper.py:119] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0923 14:26:05.985465 140684055553856 deprecation_wrapper.py:119] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0923 14:26:05.988257 140684055553856 deprecation_wrapper.py:119] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0923 14:26:06.381578 140684055553856 deprecation_wrapper.py:119] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0923 14:26:06.389057 140684055553856 deprecation.py:506] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
mc = ModelCheckpoint('update-weights_TSLA-{epoch:02d}-{val_loss:.2f}.hdf5',
                      monitor='val_loss',
                      mode='min',
                      verbose=1,
                      save_best_only=True)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# W0923 14:26:06.847067 140684055553856 deprecation_wrapper.py:119] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit_generator(train_data_generator,
                              epochs =200,
                              validation_data = test_data_generator,
                              verbose=1,
                              callbacks = [es, mc])
# Out:
# W0923 14:26:07.149762 140684055553856 deprecation.py:323] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0923 14:26:09.234265 140684055553856 deprecation_wrapper.py:119] From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/200
# 281/281 [==============================] - 31s 110ms/step - loss: 9348.4915 - val_loss: 4844.6523
#
# Epoch 00001: val_loss improved from inf to 4844.65231, saving model to update-weights_TSLA-01-4844.65.hdf5
# Epoch 2/200
# 281/281 [==============================] - 26s 92ms/step - loss: 1450.8499 - val_loss: 4464.0481
#
# Epoch 00002: val_loss improved from 4844.65231 to 4464.04810, saving model to update-weights_TSLA-02-4464.05.hdf5
# Epoch 3/200
# 281/281 [==============================] - 26s 91ms/step - loss: 1149.0697 - val_loss: 19987.6695
#
# Epoch 00003: val_loss did not improve from 4464.04810
# Epoch 4/200
# 281/281 [==============================] - 25s 90ms/step - loss: 1051.7492 - val_loss: 5179.6691
#
# Epoch 00004: val_loss did not improve from 4464.04810
# Epoch 5/200
# 281/281 [==============================] - 25s 90ms/step - loss: 851.2889 - val_loss: 2607.2428
#
# Epoch 00005: val_loss improved from 4464.04810 to 2607.24285, saving model to update-weights_TSLA-05-2607.24.hdf5
# Epoch 6/200
# 281/281 [==============================] - 25s 90ms/step - loss: 983.5574 - val_loss: 2026.5547
#
# Epoch 00006: val_loss improved from 2607.24285 to 2026.55465, saving model to update-weights_TSLA-06-2026.55.hdf5
# Epoch 7/200
# 281/281 [==============================] - 25s 90ms/step - loss: 851.8506 - val_loss: 5886.9000
#
# Epoch 00007: val_loss did not improve from 2026.55465
# Epoch 8/200
# 281/281 [==============================] - 25s 89ms/step - loss: 870.0135 - val_loss: 3127.7457
#
# Epoch 00008: val_loss did not improve from 2026.55465
# Epoch 9/200
# 281/281 [==============================] - 25s 90ms/step - loss: 823.3398 - val_loss: 3414.4690
#
# Epoch 00009: val_loss did not improve from 2026.55465
# Epoch 10/200
# 281/281 [==============================] - 25s 90ms/step - loss: 749.7335 - val_loss: 1364.2139
#
# Epoch 00010: val_loss improved from 2026.55465 to 1364.21388, saving model to update-weights_TSLA-10-1364.21.hdf5
# Epoch 11/200
# 281/281 [==============================] - 25s 89ms/step - loss: 716.3813 - val_loss: 1956.9643
#
# Epoch 00011: val_loss did not improve from 1364.21388
# Epoch 12/200
# 281/281 [==============================] - 25s 90ms/step - loss: 852.2766 - val_loss: 867.8857
#
# Epoch 00012: val_loss improved from 1364.21388 to 867.88569, saving model to update-weights_TSLA-12-867.89.hdf5
# Epoch 13/200
# 281/281 [==============================] - 25s 89ms/step - loss: 929.0031 - val_loss: 905.4369
#
# Epoch 00013: val_loss did not improve from 867.88569
# Epoch 14/200
# 281/281 [==============================] - 25s 90ms/step - loss: 752.1128 - val_loss: 967.8507
#
# Epoch 00014: val_loss did not improve from 867.88569
# Epoch 15/200
# 281/281 [==============================] - 25s 90ms/step - loss: 673.0686 - val_loss: 890.8860
#
# Epoch 00015: val_loss did not improve from 867.88569
# Epoch 16/200
# 281/281 [==============================] - 25s 89ms/step - loss: 722.5967 - val_loss: 1457.4063
#
# Epoch 00016: val_loss did not improve from 867.88569
# Epoch 17/200
# 281/281 [==============================] - 25s 89ms/step - loss: 789.9837 - val_loss: 906.4563
#
# Epoch 00017: val_loss did not improve from 867.88569
# Epoch 18/200
# 281/281 [==============================] - 25s 89ms/step - loss: 779.3409 - val_loss: 8794.8635
#
# Epoch 00018: val_loss did not improve from 867.88569
# Epoch 19/200
# 281/281 [==============================] - 25s 89ms/step - loss: 946.9720 - val_loss: 1032.1797
#
# Epoch 00019: val_loss did not improve from 867.88569
# Epoch 20/200
# 281/281 [==============================] - 25s 89ms/step - loss: 830.4278 - val_loss: 2199.2930
#
# Epoch 00020: val_loss did not improve from 867.88569
# Epoch 21/200
# 281/281 [==============================] - 25s 89ms/step - loss: 627.4838 - val_loss: 2169.2332
#
# Epoch 00021: val_loss did not improve from 867.88569
# Epoch 22/200
# 281/281 [==============================] - 25s 89ms/step - loss: 673.8253 - val_loss: 898.1594
#
# Epoch 00022: val_loss did not improve from 867.88569
# Epoch 23/200
# 281/281 [==============================] - 25s 89ms/step - loss: 960.1139 - val_loss: 1063.3423
#
# Epoch 00023: val_loss did not improve from 867.88569
# Epoch 24/200
# 281/281 [==============================] - 25s 89ms/step - loss: 715.4284 - val_loss: 1276.1094
#
# Epoch 00024: val_loss did not improve from 867.88569
# Epoch 25/200
# 281/281 [==============================] - 25s 88ms/step - loss: 750.7513 - val_loss: 899.7558
#
# Epoch 00025: val_loss did not improve from 867.88569
# Epoch 26/200
# 281/281 [==============================] - 25s 89ms/step - loss: 20366.8138 - val_loss: 19783.6320
#
# Epoch 00026: val_loss did not improve from 867.88569
# Epoch 27/200
# 281/281 [==============================] - 25s 90ms/step - loss: 2116.4804 - val_loss: 1998.0943
#
# Epoch 00027: val_loss did not improve from 867.88569
# Epoch 28/200
# 281/281 [==============================] - 25s 88ms/step - loss: 1424.0569 - val_loss: 3820.1431
#
# Epoch 00028: val_loss did not improve from 867.88569
# Epoch 29/200
# 281/281 [==============================] - 25s 89ms/step - loss: 1295.5447 - val_loss: 1090.2442
#
# Epoch 00029: val_loss did not improve from 867.88569
# Epoch 30/200
# 281/281 [==============================] - 25s 89ms/step - loss: 1028.8680 - val_loss: 1205.9178
#
# Epoch 00030: val_loss did not improve from 867.88569
# Epoch 31/200
# 281/281 [==============================] - 25s 89ms/step - loss: 973.7548 - val_loss: 1053.5195
#
# Epoch 00031: val_loss did not improve from 867.88569
# Epoch 32/200
# 281/281 [==============================] - 25s 89ms/step - loss: 896.7830 - val_loss: 1228.3724
#
# Epoch 00032: val_loss did not improve from 867.88569
# Epoch 33/200
# 281/281 [==============================] - 25s 90ms/step - loss: 1005.6668 - val_loss: 1673.3338
#
# Epoch 00033: val_loss did not improve from 867.88569
# Epoch 34/200
# 281/281 [==============================] - 25s 89ms/step - loss: 1104.8909 - val_loss: 2007.9038
#
# Epoch 00034: val_loss did not improve from 867.88569
# Epoch 35/200
# 281/281 [==============================] - 25s 89ms/step - loss: 924.2924 - val_loss: 1318.3667
#
# Epoch 00035: val_loss did not improve from 867.88569
# Epoch 36/200
# 281/281 [==============================] - 25s 89ms/step - loss: 823.6895 - val_loss: 886.5131
#
# Epoch 00036: val_loss did not improve from 867.88569
# Epoch 37/200
# 281/281 [==============================] - 25s 90ms/step - loss: 897.8612 - val_loss: 2129.7386
#
# Epoch 00037: val_loss did not improve from 867.88569
# Epoch 38/200
# 281/281 [==============================] - 25s 89ms/step - loss: 854.4217 - val_loss: 2060.9594
#
# Epoch 00038: val_loss did not improve from 867.88569
# Epoch 39/200
# 281/281 [==============================] - 25s 89ms/step - loss: 742.6015 - val_loss: 2658.5200
#
# Epoch 00039: val_loss did not improve from 867.88569
# Epoch 40/200
# 281/281 [==============================] - 25s 89ms/step - loss: 885.8806 - val_loss: 3446.1480
#
# Epoch 00040: val_loss did not improve from 867.88569
# Epoch 41/200
# 281/281 [==============================] - 25s 89ms/step - loss: 835.1250 - val_loss: 803.1008
#
# Epoch 00041: val_loss improved from 867.88569 to 803.10083, saving model to update-weights_TSLA-41-803.10.hdf5
# Epoch 42/200
# 281/281 [==============================] - 26s 91ms/step - loss: 823.9367 - val_loss: 1345.0226
#
# Epoch 00042: val_loss did not improve from 803.10083
# Epoch 43/200
# 281/281 [==============================] - 26s 91ms/step - loss: 729.5657 - val_loss: 1174.4035
#
# Epoch 00043: val_loss did not improve from 803.10083
# Epoch 44/200
# 281/281 [==============================] - 25s 89ms/step - loss: 837.7622 - val_loss: 6880.2508
#
# Epoch 00044: val_loss did not improve from 803.10083
# Epoch 45/200
# 281/281 [==============================] - 25s 89ms/step - loss: 814.9114 - val_loss: 1513.3361
#
# Epoch 00045: val_loss did not improve from 803.10083
# Epoch 46/200
# 281/281 [==============================] - 25s 90ms/step - loss: 790.1540 - val_loss: 3294.7773
#
# Epoch 00046: val_loss did not improve from 803.10083
# Epoch 47/200
# 281/281 [==============================] - 25s 89ms/step - loss: 755.2901 - val_loss: 1597.4296
#
# Epoch 00047: val_loss did not improve from 803.10083
# Epoch 48/200
# 281/281 [==============================] - 25s 90ms/step - loss: 965.6120 - val_loss: 3190.4030
#
# Epoch 00048: val_loss did not improve from 803.10083
# Epoch 49/200
# 281/281 [==============================] - 25s 90ms/step - loss: 875.8125 - val_loss: 646.4314
#
# Epoch 00049: val_loss improved from 803.10083 to 646.43141, saving model to update-weights_TSLA-49-646.43.hdf5
# Epoch 50/200
# 281/281 [==============================] - 25s 89ms/step - loss: 834.8961 - val_loss: 804.4307
#
# Epoch 00050: val_loss did not improve from 646.43141
# Epoch 51/200
# 281/281 [==============================] - 25s 90ms/step - loss: 678.8498 - val_loss: 1791.5332
#
# Epoch 00051: val_loss did not improve from 646.43141
# Epoch 52/200
# 281/281 [==============================] - 25s 90ms/step - loss: 737.8199 - val_loss: 3357.1134
#
# Epoch 00052: val_loss did not improve from 646.43141
# Epoch 53/200
# 281/281 [==============================] - 25s 89ms/step - loss: 743.6026 - val_loss: 2224.9255
#
# Epoch 00053: val_loss did not improve from 646.43141
# Epoch 54/200
# 281/281 [==============================] - 25s 89ms/step - loss: 676.4090 - val_loss: 1392.5018
#
# Epoch 00054: val_loss did not improve from 646.43141
# Epoch 55/200
# 281/281 [==============================] - 25s 89ms/step - loss: 627.1688 - val_loss: 881.1409
#
# Epoch 00055: val_loss did not improve from 646.43141
# Epoch 56/200
# 281/281 [==============================] - 25s 89ms/step - loss: 674.2218 - val_loss: 3549.5272
#
# Epoch 00056: val_loss did not improve from 646.43141
# Epoch 57/200
# 281/281 [==============================] - 25s 89ms/step - loss: 734.7754 - val_loss: 654.5936
#
# Epoch 00057: val_loss did not improve from 646.43141
# Epoch 58/200
# 281/281 [==============================] - 25s 89ms/step - loss: 609.3947 - val_loss: 2676.1748
#
# Epoch 00058: val_loss did not improve from 646.43141
# Epoch 59/200
# 281/281 [==============================] - 26s 91ms/step - loss: 607.8221 - val_loss: 2646.4551
#
# Epoch 00059: val_loss did not improve from 646.43141
# Epoch 60/200
# 281/281 [==============================] - 26s 91ms/step - loss: 717.9421 - val_loss: 1685.9986
#
# Epoch 00060: val_loss did not improve from 646.43141
# Epoch 61/200
# 281/281 [==============================] - 26s 92ms/step - loss: 613.9957 - val_loss: 1041.3717
#
# Epoch 00061: val_loss did not improve from 646.43141
# Epoch 62/200
# 281/281 [==============================] - 25s 91ms/step - loss: 522.2189 - val_loss: 2553.7956
#
# Epoch 00062: val_loss did not improve from 646.43141
# Epoch 63/200
# 281/281 [==============================] - 26s 91ms/step - loss: 636.5334 - val_loss: 837.5361
#
# Epoch 00063: val_loss did not improve from 646.43141
# Epoch 64/200
# 281/281 [==============================] - 25s 90ms/step - loss: 646.4576 - val_loss: 1712.2510
#
# Epoch 00064: val_loss did not improve from 646.43141
# Epoch 65/200
# 281/281 [==============================] - 25s 89ms/step - loss: 522.2336 - val_loss: 1156.4069
#
# Epoch 00065: val_loss did not improve from 646.43141
# Epoch 66/200
# 281/281 [==============================] - 25s 90ms/step - loss: 610.1627 - val_loss: 7262.7324
#
# Epoch 00066: val_loss did not improve from 646.43141
# Epoch 67/200
# 281/281 [==============================] - 26s 92ms/step - loss: 741.0442 - val_loss: 702.0142
#
# Epoch 00067: val_loss did not improve from 646.43141
# Epoch 68/200
# 281/281 [==============================] - 26s 91ms/step - loss: 575.6989 - val_loss: 690.6587
#
# Epoch 00068: val_loss did not improve from 646.43141
# Epoch 69/200
# 281/281 [==============================] - 25s 90ms/step - loss: 626.5223 - val_loss: 647.6841
#
# Epoch 00069: val_loss did not improve from 646.43141
# Epoch 70/200
# 281/281 [==============================] - 25s 90ms/step - loss: 619.8210 - val_loss: 1262.0736
#
# Epoch 00070: val_loss did not improve from 646.43141
# Epoch 71/200
# 281/281 [==============================] - 25s 90ms/step - loss: 526.3664 - val_loss: 2684.9666
#
# Epoch 00071: val_loss did not improve from 646.43141
# Epoch 72/200
# 281/281 [==============================] - 25s 89ms/step - loss: 573.8107 - val_loss: 2115.4080
#
# Epoch 00072: val_loss did not improve from 646.43141
# Epoch 73/200
# 281/281 [==============================] - 25s 90ms/step - loss: 641.2168 - val_loss: 6848.5651
#
# Epoch 00073: val_loss did not improve from 646.43141
# Epoch 74/200
# 281/281 [==============================] - 25s 89ms/step - loss: 623.4616 - val_loss: 2253.2947
#
# Epoch 00074: val_loss did not improve from 646.43141
# Epoch 75/200
# 281/281 [==============================] - 25s 89ms/step - loss: 530.4062 - val_loss: 2022.3092
#
# Epoch 00075: val_loss did not improve from 646.43141
# Epoch 76/200
# 281/281 [==============================] - 25s 89ms/step - loss: 482.9685 - val_loss: 778.6534
#
# Epoch 00076: val_loss did not improve from 646.43141
# Epoch 77/200
# 281/281 [==============================] - 25s 89ms/step - loss: 561.7488 - val_loss: 549.4511
#
# Epoch 00077: val_loss improved from 646.43141 to 549.45113, saving model to update-weights_TSLA-77-549.45.hdf5
# Epoch 78/200
# 281/281 [==============================] - 25s 90ms/step - loss: 545.1918 - val_loss: 8124.6272
#
# Epoch 00078: val_loss did not improve from 549.45113
# Epoch 79/200
# 281/281 [==============================] - 25s 89ms/step - loss: 555.3889 - val_loss: 1797.1701
#
# Epoch 00079: val_loss did not improve from 549.45113
# Epoch 80/200
# 281/281 [==============================] - 25s 90ms/step - loss: 524.6218 - val_loss: 589.2902
#
# Epoch 00080: val_loss did not improve from 549.45113
# Epoch 81/200
# 281/281 [==============================] - 25s 89ms/step - loss: 473.7602 - val_loss: 506.9181
#
# Epoch 00081: val_loss improved from 549.45113 to 506.91806, saving model to update-weights_TSLA-81-506.92.hdf5
# Epoch 82/200
# 281/281 [==============================] - 26s 91ms/step - loss: 571.2335 - val_loss: 540.7415
#
# Epoch 00082: val_loss did not improve from 506.91806
# Epoch 83/200
# 281/281 [==============================] - 25s 90ms/step - loss: 516.0574 - val_loss: 1150.7770
#
# Epoch 00083: val_loss did not improve from 506.91806
# Epoch 84/200
# 281/281 [==============================] - 26s 91ms/step - loss: 531.1055 - val_loss: 3409.4846
#
# Epoch 00084: val_loss did not improve from 506.91806
# Epoch 85/200
# 281/281 [==============================] - 25s 90ms/step - loss: 445.7003 - val_loss: 630.9890
#
# Epoch 00085: val_loss did not improve from 506.91806
# Epoch 86/200
# 281/281 [==============================] - 25s 89ms/step - loss: 550.7168 - val_loss: 446.2384
#
# Epoch 00086: val_loss improved from 506.91806 to 446.23842, saving model to update-weights_TSLA-86-446.24.hdf5
# Epoch 87/200
# 281/281 [==============================] - 25s 90ms/step - loss: 434.2189 - val_loss: 2619.5767
#
# Epoch 00087: val_loss did not improve from 446.23842
# Epoch 88/200
# 281/281 [==============================] - 25s 90ms/step - loss: 426.3184 - val_loss: 4482.1523
#
# Epoch 00088: val_loss did not improve from 446.23842
# Epoch 89/200
# 281/281 [==============================] - 25s 89ms/step - loss: 474.9383 - val_loss: 2911.5467
#
# Epoch 00089: val_loss did not improve from 446.23842
# Epoch 90/200
# 281/281 [==============================] - 25s 89ms/step - loss: 420.1908 - val_loss: 4607.4664
#
# Epoch 00090: val_loss did not improve from 446.23842
# Epoch 91/200
# 281/281 [==============================] - 25s 89ms/step - loss: 478.3498 - val_loss: 931.7113
#
# Epoch 00091: val_loss did not improve from 446.23842
# Epoch 92/200
# 281/281 [==============================] - 25s 89ms/step - loss: 500.1709 - val_loss: 1801.9784
#
# Epoch 00092: val_loss did not improve from 446.23842
# Epoch 93/200
# 281/281 [==============================] - 25s 89ms/step - loss: 477.7260 - val_loss: 1169.9048
#
# Epoch 00093: val_loss did not improve from 446.23842
# Epoch 94/200
# 281/281 [==============================] - 25s 89ms/step - loss: 459.0051 - val_loss: 1348.0339
#
# Epoch 00094: val_loss did not improve from 446.23842
# Epoch 95/200
# 281/281 [==============================] - 25s 89ms/step - loss: 430.3077 - val_loss: 2130.3511
#
# Epoch 00095: val_loss did not improve from 446.23842
# Epoch 96/200
# 281/281 [==============================] - 25s 89ms/step - loss: 490.2287 - val_loss: 4381.2844
#
# Epoch 00096: val_loss did not improve from 446.23842
# Epoch 97/200
# 281/281 [==============================] - 24s 87ms/step - loss: 545.7568 - val_loss: 6058.3595
#
# Epoch 00097: val_loss did not improve from 446.23842
# Epoch 98/200
# 281/281 [==============================] - 20s 72ms/step - loss: 510.4686 - val_loss: 1867.6037
#
# Epoch 00098: val_loss did not improve from 446.23842
# Epoch 99/200
# 281/281 [==============================] - 20s 72ms/step - loss: 479.3844 - val_loss: 2973.6840
#
# Epoch 00099: val_loss did not improve from 446.23842
# Epoch 100/200
# 281/281 [==============================] - 20s 72ms/step - loss: 434.1611 - val_loss: 2749.1300
#
# Epoch 00100: val_loss did not improve from 446.23842
# Epoch 101/200
# 281/281 [==============================] - 20s 73ms/step - loss: 463.1868 - val_loss: 2662.4715
#
# Epoch 00101: val_loss did not improve from 446.23842
# Epoch 102/200
# 281/281 [==============================] - 21s 74ms/step - loss: 481.0425 - val_loss: 1098.4887
#
# Epoch 00102: val_loss did not improve from 446.23842
# Epoch 103/200
# 281/281 [==============================] - 21s 73ms/step - loss: 521.7162 - val_loss: 1393.5659
#
# Epoch 00103: val_loss did not improve from 446.23842
# Epoch 104/200
# 281/281 [==============================] - 21s 74ms/step - loss: 443.4412 - val_loss: 1980.8849
#
# Epoch 00104: val_loss did not improve from 446.23842
# Epoch 105/200
# 281/281 [==============================] - 21s 74ms/step - loss: 436.4721 - val_loss: 2443.9534
#
# Epoch 00105: val_loss did not improve from 446.23842
# Epoch 106/200
# 281/281 [==============================] - 21s 74ms/step - loss: 447.7265 - val_loss: 2348.8676
#
# Epoch 00106: val_loss did not improve from 446.23842
# Epoch 107/200
# 281/281 [==============================] - 21s 74ms/step - loss: 432.0416 - val_loss: 2017.7131
#
# Epoch 00107: val_loss did not improve from 446.23842
# Epoch 108/200
# 281/281 [==============================] - 21s 75ms/step - loss: 512.4288 - val_loss: 2861.5680
#
# Epoch 00108: val_loss did not improve from 446.23842
# Epoch 109/200
# 281/281 [==============================] - 21s 75ms/step - loss: 480.1444 - val_loss: 3628.7525
#
# Epoch 00109: val_loss did not improve from 446.23842
# Epoch 110/200
# 281/281 [==============================] - 21s 74ms/step - loss: 444.7079 - val_loss: 4206.0787
#
# Epoch 00110: val_loss did not improve from 446.23842
# Epoch 111/200
# 281/281 [==============================] - 21s 73ms/step - loss: 467.3654 - val_loss: 3022.1669
#
# Epoch 00111: val_loss did not improve from 446.23842
# Epoch 112/200
# 281/281 [==============================] - 21s 74ms/step - loss: 456.2435 - val_loss: 619.2670
#
# Epoch 00112: val_loss did not improve from 446.23842
# Epoch 113/200
# 281/281 [==============================] - 21s 74ms/step - loss: 443.5287 - val_loss: 782.2458
#
# Epoch 00113: val_loss did not improve from 446.23842
# Epoch 114/200
# 281/281 [==============================] - 21s 74ms/step - loss: 446.4531 - val_loss: 2908.8379
#
# Epoch 00114: val_loss did not improve from 446.23842
# Epoch 115/200
# 281/281 [==============================] - 21s 74ms/step - loss: 428.4529 - val_loss: 2465.9288
#
# Epoch 00115: val_loss did not improve from 446.23842
# Epoch 116/200
# 281/281 [==============================] - 21s 74ms/step - loss: 426.3909 - val_loss: 3328.4183
#
# Epoch 00116: val_loss did not improve from 446.23842
# Epoch 117/200
# 281/281 [==============================] - 21s 75ms/step - loss: 429.7910 - val_loss: 2840.6164
#
# Epoch 00117: val_loss did not improve from 446.23842
# Epoch 118/200
# 281/281 [==============================] - 21s 75ms/step - loss: 409.9120 - val_loss: 2166.2537
#
# Epoch 00118: val_loss did not improve from 446.23842
# Epoch 119/200
# 281/281 [==============================] - 21s 74ms/step - loss: 488.5607 - val_loss: 1692.1272
#
# Epoch 00119: val_loss did not improve from 446.23842
# Epoch 120/200
# 281/281 [==============================] - 20s 71ms/step - loss: 453.9713 - val_loss: 2938.2372
#
# Epoch 00120: val_loss did not improve from 446.23842
# Epoch 121/200
# 281/281 [==============================] - 20s 72ms/step - loss: 449.7669 - val_loss: 1623.7523
#
# Epoch 00121: val_loss did not improve from 446.23842
# Epoch 122/200
# 281/281 [==============================] - 20s 71ms/step - loss: 381.4680 - val_loss: 476.1512
#
# Epoch 00122: val_loss did not improve from 446.23842
# Epoch 123/200
# 281/281 [==============================] - 20s 71ms/step - loss: 508.6636 - val_loss: 2011.5441
#
# Epoch 00123: val_loss did not improve from 446.23842
# Epoch 124/200
# 281/281 [==============================] - 20s 72ms/step - loss: 465.2217 - val_loss: 8758.1788
#
# Epoch 00124: val_loss did not improve from 446.23842
# Epoch 125/200
# 281/281 [==============================] - 20s 71ms/step - loss: 417.8805 - val_loss: 3157.0623
#
# Epoch 00125: val_loss did not improve from 446.23842
# Epoch 126/200
# 281/281 [==============================] - 20s 71ms/step - loss: 440.6652 - val_loss: 5729.04742s - l - ETA: 1s - loss:  - ETA:
#
# Epoch 00126: val_loss did not improve from 446.23842
# Epoch 127/200
# 281/281 [==============================] - 20s 71ms/step - loss: 464.0445 - val_loss: 1721.3673
#
# Epoch 00127: val_loss did not improve from 446.23842
# Epoch 128/200
# 281/281 [==============================] - 20s 72ms/step - loss: 403.5646 - val_loss: 439.7608
#
# Epoch 00128: val_loss improved from 446.23842 to 439.76084, saving model to update-weights_TSLA-128-439.76.hdf5
# Epoch 129/200
# 281/281 [==============================] - 21s 75ms/step - loss: 423.4231 - val_loss: 6491.8477
#
# Epoch 00129: val_loss did not improve from 439.76084
# Epoch 130/200
# 281/281 [==============================] - 21s 74ms/step - loss: 419.5787 - val_loss: 2564.6053
#
# Epoch 00130: val_loss did not improve from 439.76084
# Epoch 131/200
# 281/281 [==============================] - 21s 74ms/step - loss: 463.6802 - val_loss: 2545.2795
#
# Epoch 00131: val_loss did not improve from 439.76084
# Epoch 132/200
# 281/281 [==============================] - 21s 74ms/step - loss: 399.4806 - val_loss: 3962.9373
#
# Epoch 00132: val_loss did not improve from 439.76084
# Epoch 133/200
# 281/281 [==============================] - 21s 74ms/step - loss: 437.2984 - val_loss: 2937.9340
#
# Epoch 00133: val_loss did not improve from 439.76084
# Epoch 134/200
# 281/281 [==============================] - 21s 74ms/step - loss: 414.2108 - val_loss: 3908.1277
#
# Epoch 00134: val_loss did not improve from 439.76084
# Epoch 135/200
# 281/281 [==============================] - 20s 72ms/step - loss: 427.4468 - val_loss: 2427.5741
#
# Epoch 00135: val_loss did not improve from 439.76084
# Epoch 136/200
# 281/281 [==============================] - 21s 74ms/step - loss: 420.9983 - val_loss: 3887.1746
#
# Epoch 00136: val_loss did not improve from 439.76084
# Epoch 137/200
# 281/281 [==============================] - 21s 74ms/step - loss: 402.2034 - val_loss: 3264.7968
#
# Epoch 00137: val_loss did not improve from 439.76084
# Epoch 138/200
# 281/281 [==============================] - 21s 74ms/step - loss: 515.3549 - val_loss: 4564.3814
#
# Epoch 00138: val_loss did not improve from 439.76084
# Epoch 139/200
# 281/281 [==============================] - 21s 75ms/step - loss: 447.1171 - val_loss: 6166.4042
#
# Epoch 00139: val_loss did not improve from 439.76084
# Epoch 140/200
# 281/281 [==============================] - 21s 74ms/step - loss: 397.2908 - val_loss: 6111.1952
#
# Epoch 00140: val_loss did not improve from 439.76084
# Epoch 141/200
# 281/281 [==============================] - 21s 74ms/step - loss: 421.9106 - val_loss: 1962.5260
#
# Epoch 00141: val_loss did not improve from 439.76084
# Epoch 142/200
# 281/281 [==============================] - 21s 74ms/step - loss: 418.3728 - val_loss: 3933.1394
#
# Epoch 00142: val_loss did not improve from 439.76084
# Epoch 143/200
# 281/281 [==============================] - 21s 74ms/step - loss: 377.2568 - val_loss: 3639.0413
#
# Epoch 00143: val_loss did not improve from 439.76084
# Epoch 144/200
# 281/281 [==============================] - 21s 74ms/step - loss: 411.5011 - val_loss: 631.2723
#
# Epoch 00144: val_loss did not improve from 439.76084
# Epoch 145/200
# 281/281 [==============================] - 21s 74ms/step - loss: 453.0370 - val_loss: 3737.7013
#
# Epoch 00145: val_loss did not improve from 439.76084
# Epoch 146/200
# 281/281 [==============================] - 20s 73ms/step - loss: 390.2079 - val_loss: 1120.0100
#
# Epoch 00146: val_loss did not improve from 439.76084
# Epoch 147/200
# 281/281 [==============================] - 20s 72ms/step - loss: 392.1128 - val_loss: 1195.1728
#
# Epoch 00147: val_loss did not improve from 439.76084
# Epoch 148/200
# 281/281 [==============================] - 21s 73ms/step - loss: 436.4513 - val_loss: 2617.5691
#
# Epoch 00148: val_loss did not improve from 439.76084
# Epoch 149/200
# 281/281 [==============================] - 20s 72ms/step - loss: 422.0376 - val_loss: 2452.6169
#
# Epoch 00149: val_loss did not improve from 439.76084
# Epoch 150/200
# 281/281 [==============================] - 20s 71ms/step - loss: 484.1190 - val_loss: 4031.4329
#
# Epoch 00150: val_loss did not improve from 439.76084
# Epoch 151/200
# 281/281 [==============================] - 21s 73ms/step - loss: 408.0393 - val_loss: 3705.6671
#
# Epoch 00151: val_loss did not improve from 439.76084
# Epoch 152/200
# 281/281 [==============================] - 20s 72ms/step - loss: 353.8993 - val_loss: 754.6142
#
# Epoch 00152: val_loss did not improve from 439.76084
# Epoch 153/200
# 281/281 [==============================] - 21s 74ms/step - loss: 357.5275 - val_loss: 2872.8339
#
# Epoch 00153: val_loss did not improve from 439.76084
# Epoch 154/200
# 281/281 [==============================] - 21s 74ms/step - loss: 356.7318 - val_loss: 3015.0210
#
# Epoch 00154: val_loss did not improve from 439.76084
# Epoch 155/200
# 281/281 [==============================] - 21s 74ms/step - loss: 371.3815 - val_loss: 2044.5849
#
# Epoch 00155: val_loss did not improve from 439.76084
# Epoch 156/200
# 281/281 [==============================] - 21s 74ms/step - loss: 367.1151 - val_loss: 679.6122
#
# Epoch 00156: val_loss did not improve from 439.76084
# Epoch 157/200
# 281/281 [==============================] - 21s 74ms/step - loss: 353.0276 - val_loss: 498.1777
#
# Epoch 00157: val_loss did not improve from 439.76084
# Epoch 158/200
# 281/281 [==============================] - 21s 74ms/step - loss: 410.0653 - val_loss: 6573.8417
#
# Epoch 00158: val_loss did not improve from 439.76084
# Epoch 159/200
# 281/281 [==============================] - 21s 75ms/step - loss: 373.5787 - val_loss: 3404.3477
#
# Epoch 00159: val_loss did not improve from 439.76084
# Epoch 160/200
# 281/281 [==============================] - 21s 74ms/step - loss: 373.8409 - val_loss: 1539.6980
#
# Epoch 00160: val_loss did not improve from 439.76084
# Epoch 161/200
# 281/281 [==============================] - 21s 73ms/step - loss: 344.9831 - val_loss: 2754.3433
#
# Epoch 00161: val_loss did not improve from 439.76084
# Epoch 162/200
# 281/281 [==============================] - 21s 74ms/step - loss: 393.4599 - val_loss: 4704.1489
#
# Epoch 00162: val_loss did not improve from 439.76084
# Epoch 163/200
# 281/281 [==============================] - 21s 74ms/step - loss: 387.4743 - val_loss: 8994.2216
#
# Epoch 00163: val_loss did not improve from 439.76084
# Epoch 164/200
# 281/281 [==============================] - 21s 73ms/step - loss: 434.3553 - val_loss: 1915.6976
#
# Epoch 00164: val_loss did not improve from 439.76084
# Epoch 165/200
# 281/281 [==============================] - 21s 73ms/step - loss: 412.3687 - val_loss: 2923.9717
#
# Epoch 00165: val_loss did not improve from 439.76084
# Epoch 166/200
# 281/281 [==============================] - 20s 73ms/step - loss: 393.4835 - val_loss: 950.7646
#
# Epoch 00166: val_loss did not improve from 439.76084
# Epoch 167/200
# 281/281 [==============================] - 21s 73ms/step - loss: 380.3282 - val_loss: 2211.0196
#
# Epoch 00167: val_loss did not improve from 439.76084
# Epoch 168/200
# 281/281 [==============================] - 21s 73ms/step - loss: 463.1305 - val_loss: 2853.7810
#
# Epoch 00168: val_loss did not improve from 439.76084
# Epoch 169/200
# 281/281 [==============================] - 21s 74ms/step - loss: 401.7865 - val_loss: 1500.7348
#
# Epoch 00169: val_loss did not improve from 439.76084
# Epoch 170/200
# 281/281 [==============================] - 21s 74ms/step - loss: 453.3078 - val_loss: 2774.8017
#
# Epoch 00170: val_loss did not improve from 439.76084
# Epoch 171/200
# 281/281 [==============================] - 21s 73ms/step - loss: 413.6329 - val_loss: 2870.7359
#
# Epoch 00171: val_loss did not improve from 439.76084
# Epoch 172/200
# 281/281 [==============================] - 21s 73ms/step - loss: 365.2177 - val_loss: 3803.8465
#
# Epoch 00172: val_loss did not improve from 439.76084
# Epoch 173/200
# 281/281 [==============================] - 21s 73ms/step - loss: 400.8673 - val_loss: 2356.4561
#
# Epoch 00173: val_loss did not improve from 439.76084
# Epoch 174/200
# 281/281 [==============================] - 21s 74ms/step - loss: 402.1092 - val_loss: 5137.9111
#
# Epoch 00174: val_loss did not improve from 439.76084
# Epoch 175/200
# 281/281 [==============================] - 21s 74ms/step - loss: 374.6911 - val_loss: 1854.8372
#
# Epoch 00175: val_loss did not improve from 439.76084
# Epoch 176/200
# 281/281 [==============================] - 21s 74ms/step - loss: 371.9416 - val_loss: 2419.9070
#
# Epoch 00176: val_loss did not improve from 439.76084
# Epoch 177/200
# 281/281 [==============================] - 21s 74ms/step - loss: 369.6489 - val_loss: 1314.3786
#
# Epoch 00177: val_loss did not improve from 439.76084
# Epoch 178/200
# 281/281 [==============================] - 21s 74ms/step - loss: 387.4794 - val_loss: 1536.2366
#
# Epoch 00178: val_loss did not improve from 439.76084
# Epoch 179/200
# 281/281 [==============================] - 21s 73ms/step - loss: 402.6584 - val_loss: 903.2981
#
# Epoch 00179: val_loss did not improve from 439.76084
# Epoch 180/200
# 281/281 [==============================] - 21s 74ms/step - loss: 7106.5412 - val_loss: 23763.4318
#
# Epoch 00180: val_loss did not improve from 439.76084
# Epoch 181/200
# 281/281 [==============================] - 21s 75ms/step - loss: 3834.1543 - val_loss: 6044.6987
#
# Epoch 00181: val_loss did not improve from 439.76084
# Epoch 182/200
# 281/281 [==============================] - 21s 74ms/step - loss: 5668.2214 - val_loss: 11025.8833
#
# Epoch 00182: val_loss did not improve from 439.76084
# Epoch 183/200
# 281/281 [==============================] - 21s 74ms/step - loss: 4142.3185 - val_loss: 7759.0411
#
# Epoch 00183: val_loss did not improve from 439.76084
# Epoch 184/200
# 281/281 [==============================] - 20s 73ms/step - loss: 3549.8366 - val_loss: 3503.5362
#
# Epoch 00184: val_loss did not improve from 439.76084
# Epoch 185/200
# 281/281 [==============================] - 21s 74ms/step - loss: 3444.4514 - val_loss: 1598.2903
#
# Epoch 00185: val_loss did not improve from 439.76084
# Epoch 186/200
# 281/281 [==============================] - 21s 74ms/step - loss: 4492.0112 - val_loss: 5060.9423
#
# Epoch 00186: val_loss did not improve from 439.76084
# Epoch 187/200
# 281/281 [==============================] - 21s 74ms/step - loss: 3902.5883 - val_loss: 14031.8391
#
# Epoch 00187: val_loss did not improve from 439.76084
# Epoch 188/200
# 281/281 [==============================] - 21s 74ms/step - loss: 12484.6966 - val_loss: 19171.0016
#
# Epoch 00188: val_loss did not improve from 439.76084
# Epoch 189/200
# 281/281 [==============================] - 21s 74ms/step - loss: 5140.2716 - val_loss: 6503.6402
#
# Epoch 00189: val_loss did not improve from 439.76084
# Epoch 190/200
# 281/281 [==============================] - 20s 73ms/step - loss: 2950.5617 - val_loss: 11781.9995
#
# Epoch 00190: val_loss did not improve from 439.76084
# Epoch 191/200
# 281/281 [==============================] - 21s 73ms/step - loss: 3437.3380 - val_loss: 7944.1794
#
# Epoch 00191: val_loss did not improve from 439.76084
# Epoch 192/200
# 281/281 [==============================] - 21s 74ms/step - loss: 2301.3575 - val_loss: 10166.4197
#
# Epoch 00192: val_loss did not improve from 439.76084
# Epoch 193/200
# 281/281 [==============================] - 21s 74ms/step - loss: 2697.1155 - val_loss: 10100.9951
#
# Epoch 00193: val_loss did not improve from 439.76084
# Epoch 194/200
# 281/281 [==============================] - 21s 74ms/step - loss: 1697.0555 - val_loss: 3695.4834
#
# Epoch 00194: val_loss did not improve from 439.76084
# Epoch 195/200
# 281/281 [==============================] - 21s 75ms/step - loss: 1386.2818 - val_loss: 3951.9544
#
# Epoch 00195: val_loss did not improve from 439.76084
# Epoch 196/200
# 281/281 [==============================] - 21s 74ms/step - loss: 1435.5875 - val_loss: 11748.7337
#
# Epoch 00196: val_loss did not improve from 439.76084
# Epoch 197/200
# 281/281 [==============================] - 21s 75ms/step - loss: 1280.4783 - val_loss: 10776.5699
#
# Epoch 00197: val_loss did not improve from 439.76084
# Epoch 198/200
# 281/281 [==============================] - 21s 75ms/step - loss: 1419.6415 - val_loss: 5563.3315
#
# Epoch 00198: val_loss did not improve from 439.76084
# Epoch 199/200
# 281/281 [==============================] - 21s 74ms/step - loss: 1167.2284 - val_loss: 3864.4255
#
# Epoch 00199: val_loss did not improve from 439.76084
# Epoch 200/200
# 281/281 [==============================] - 21s 74ms/step - loss: 951.8251 - val_loss: 3402.3860
#
# Epoch 00200: val_loss did not improve from 439.76084

# %%
import matplotlib.pyplot as plt

# %%
# plot the training
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test', color = 'teal')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,12))
y_pred = model.predict_generator(test_data_generator)
for i in range(30):
    y_pred = np.insert(y_pred, 0, [0], axis=0)
    
plt.plot(y_pred)
plt.plot(y_test);

# %% [markdown]
# ## Shapley

# %%
def extract_data(generator):
    for i in np.arange(len(generator)):
        if i == 0:
            a, b = generator[i]
        else: 
            c, d = generator[i]

            a = np.vstack((a, c))
            b = np.vstack((b, d))
            
    return a, b

# %%
def individual_array(sample):
    
    # get the means for each sampling
    for i in np.arange(len(sample[0])):
        means = []
        for j in np.arange(len (sample)):
            means.append(sample[j][i])
        s_value = np.array(np.mean(means))

        if i == 0:
            final_array = s_value
        else:
            final_array = np.hstack((final_array, s_value))
            
    return final_array

# %%
def flatten_shap_values(shap_vals):
    
    #Pull the array out of the list. 
    sv = shap_vals[0]
    
    count = 0
    for sample in sv: 
        sample_array = individual_array(sample)
        if count == 0:
            final_array = sample_array
        else:
            final_array = np.vstack((final_array, sample_array))
        
        count +=1
        
    return final_array

# %%
a, b = extract_data(test_data_generator)

# %%
a.shape
# Out:
# (240, 15, 64)

# %%
b.shape
# Out:
# (240, 1)

# %%
from shap import DeepExplainer, summary_plot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-cdda032801d2> in <module>()
# ----> 1 from shap import DeepExplainer, summary_plot
#
# ModuleNotFoundError: No module named 'shap'

# %%
de = DeepExplainer(model = model, data=a)

shaps_vals = de.shap_values(a)

# %%
print(shaps_vals[0].shape)
print(shaps_vals[0][0].shape)
print(shaps_vals[0][0][0].shape)

# %%
summary_plot([shaps_vals[0][100]], feature_names=df.columns)

# %%
individual_array(shaps_vals[0][0])

# %%
summary_lot([flatten_shap_values(shaps_vals)],
            feature_names = (df.drop(columns=['target'])
                             .columns
                             .tolist()))

# %%
shap_df = pd.DataFrame(data=flatten_shap_values(shaps_vals),columns = df.drop(columns='target').columns.tolist())

# %%
shap_df.head()

# %%
np.save('shaps_vals', shaps_vals)
np.save('feature_gen_extracted', a)
np.save('target_gen_extracted', b)

# %%
import pca_concordance as pcac

# %%
pcac.feature_pca_concordance(a, shap_df)

# %%
import dill

# %%
shaps_vals[0]
